# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Google-Colab/blob/master/2_iterate_over_rows.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - https://www.youtube.com/watch?v=LHE0g1ghfV4
#
# - https://www.youtube.com/watch?v=1C0tjKf1D34 ---> How to process specific df column & its value in for loop

# %% [markdown]
# -----------------

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
boston = pd.read_csv("/content/drive/MyDrive/Datasets/boston.zip")
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222     18.7  396.90    NaN  36.2
#
# [5 rows x 14 columns]

# %%
for ind,row in boston.iterrows():
  boston.loc[ind, "Avg price per room"] = row['MEDV'] / row['RM']

# %%
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS  ...       B  LSTAT  MEDV  Avg price per room
# 0  0.00632  18.0   2.31   0.0  ...  396.90   4.98  24.0            3.650190
# 1  0.02731   0.0   7.07   0.0  ...  396.90   9.14  21.6            3.363962
# 2  0.02729   0.0   7.07   0.0  ...  392.83   4.03  34.7            4.829506
# 3  0.03237   0.0   2.18   0.0  ...  394.63   2.94  33.4            4.772792
# 4  0.06905   0.0   2.18   0.0  ...  396.90    NaN  36.2            5.065062
#
# [5 rows x 15 columns]

# %% [markdown]
# ---------------------

# %%
for i in boston:
  print(i)
# Out:
# CRIM
# ZN
# INDUS
# CHAS
# NOX
# RM
# AGE
# DIS
# RAD
# TAX
# PTRATIO
# B
# LSTAT
# MEDV
# Avg price per room

# %%
for ind,row in boston.iterrows():
  print(ind,row)
# Out:
# 0 CRIM                    0.00632
# ZN                     18.00000
# INDUS                   2.31000
# CHAS                    0.00000
# NOX                     0.53800
# RM                      6.57500
# AGE                    65.20000
# DIS                     4.09000
# RAD                     1.00000
# TAX                   296.00000
# PTRATIO                15.30000
# B                     396.90000
# LSTAT                   4.98000
# MEDV                   24.00000
# Avg price per room      3.65019
# Name: 0, dtype: float64
# 1 CRIM                    0.027310
# ZN                      0.000000
# INDUS                   7.070000
# CHAS                    0.000000
# NOX                     0.469000
# RM                      6.421000
# AGE                    78.900000
# DIS                     4.967100
# RAD                     2.000000
# TAX                   242.000000
# PTRATIO                17.800000
# B                     396.900000
# LSTAT                   9.140000
# MEDV                   21.600000
# Avg price per room      3.363962
# Name: 1, dtype: float64
# 2 CRIM                    0.027290
# ZN                      0.000000
# INDUS                   7.070000
# CHAS                    0.000000
# NOX                     0.469000
# RM                      7.185000
# AGE                    61.100000
# DIS                     4.967100
# RAD                     2.000000
# TAX                   242.000000
# PTRATIO                17.800000
# B                     392.830000
# LSTAT                   4.030000
# MEDV                   34.700000
# Avg price per room      4.829506
# Name: 2, dtype: float64
# 3 CRIM                    0.032370
# ZN                      0.000000
# INDUS                   2.180000
# CHAS                    0.000000
# NOX                     0.458000
# RM                      6.998000
# AGE                    45.800000
# DIS                     6.062200
# RAD                     3.000000
# TAX                   222.000000
# PTRATIO                18.700000
# B                     394.630000
# LSTAT                   2.940000
# MEDV                   33.400000
# Avg price per room      4.772792
# Name: 3, dtype: float64
# 4 CRIM                    0.069050
# ZN                      0.000000
# INDUS                   2.180000
# CHAS                    0.000000
# NOX                     0.458000
# RM                      7.147000
# AGE                    54.200000
# DIS                     6.062200
# RAD                     3.000000
# TAX                   222.000000
# PTRATIO                18.700000
# B                     396.900000
# LSTAT                        NaN
# MEDV                   36.200000
# Avg price per room      5.065062
# Name: 4, dtype: float64
# 5 CRIM                    0.029850
# ZN                      0.000000
# INDUS                   2.180000
# CHAS                    0.000000
# NOX                     0.458000
# RM                      6.430000
# AGE                    58.700000
# DIS                     6.062200
# RAD                     3.000000
# TAX                   222.000000
# PTRATIO                18.700000
# B                     394.120000
# LSTAT                   5.210000
# MEDV                   28.700000
# Avg price per room      4.463453
# Name: 5, dtype: float64
# 6 CRIM                    0.088290
# ZN                     12.500000
# INDUS                   7.870000
# CHAS                         NaN
# NOX                     0.524000
# RM                      6.012000
# AGE                    66.600000
# DIS                     5.560500
# RAD                     5.000000
# TAX                   311.000000
# PTRATIO                15.200000
# B                     395.600000
# LSTAT                  12.430000
# MEDV                   22.900000
# Avg price per room      3.809049
# Name: 6, dtype: float64
# 7 CRIM                    0.144550
# ZN                     12.500000
# INDUS                   7.870000
# CHAS                    0.000000
# NOX                     0.524000
# RM                      6.172000
# AGE                    96.100000
# DIS                     5.950500
# RAD                     5.000000
# TAX                   311.000000
# PTRATIO                15.200000
# B                     396.900000
# LSTAT                  19.150000
# MEDV                   27.100000
# Avg price per room      4.390797
# Name: 7, dtype: float64
# 8 CRIM                    0.211240
# ZN                     12.500000
# INDUS                   7.870000
# CHAS                    0.000000
# NOX                     0.524000
# RM                      5.631000
# AGE                   100.000000
# DIS                     6.082100
# RAD                     5.000000
# TAX                   311.000000
# PTRATIO                15.200000
# B                     386.630000
# LSTAT                  29.930000
# MEDV                   16.500000
# Avg price per room      2.930208
# Name: 8, dtype: float64
# 9 CRIM                    0.170040
# ZN                     12.500000
# INDUS                   7.870000
# CHAS                         NaN
# NOX                     0.524000
# RM                      6.004000
# AGE                    85.900000
# DIS                     6.592100
# RAD                     5.000000
# TAX                   311.000000
# PTRATIO                15.200000
# B                     386.710000
# LSTAT                  17.100000
# MEDV                   18.900000
# Avg price per room      3.147901
# Name: 9, dtype: float64
# 10 CRIM                    0.224890
# ZN                     12.500000
# INDUS                   7.870000
# CHAS                    0.000000
# NOX                     0.524000
# RM                      6.377000
# AGE                    94.300000
# DIS                     6.346700
# RAD                     5.000000
# TAX                   311.000000
# PTRATIO                15.200000
# B                     392.520000
# LSTAT                  20.450000
# MEDV                   15.000000
# Avg price per room      2.352203
# Name: 10, dtype: float64
# 11 CRIM                    0.117470
# ZN                     12.500000
# INDUS                   7.870000
# CHAS                    0.000000
# NOX                     0.524000
# RM                      6.009000
# AGE                    82.900000
# DIS                     6.226700
# RAD                     5.000000
# TAX                   311.000000
# PTRATIO                15.200000
# B                     396.900000
# LSTAT                  13.270000
# MEDV                   18.900000
# Avg price per room      3.145282
# Name: 11, dtype: float64
# 12 CRIM                    0.093780
# ZN                     12.500000
# INDUS                   7.870000
# CHAS                    0.000000
# NOX                     0.524000
# RM                      5.889000
# AGE                    39.000000
# DIS                     5.450900
# RAD                     5.000000
# TAX                   311.000000
# PTRATIO                15.200000
# B                     390.500000
# LSTAT                  15.710000
# MEDV                   21.700000
# Avg price per room      3.684836
# Name: 12, dtype: float64
# 13 CRIM                    0.629760
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      5.949000
# AGE                    61.800000
# DIS                     4.707500
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     396.900000
# LSTAT                   8.260000
# MEDV                   20.400000
# Avg price per room      3.429148
# Name: 13, dtype: float64
# 14 CRIM                    0.637960
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                         NaN
# NOX                     0.538000
# RM                      6.096000
# AGE                    84.500000
# DIS                     4.461900
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     380.020000
# LSTAT                  10.260000
# MEDV                   18.200000
# Avg price per room      2.985564
# Name: 14, dtype: float64
# 15 CRIM                    0.627390
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      5.834000
# AGE                    56.500000
# DIS                     4.498600
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     395.620000
# LSTAT                   8.470000
# MEDV                   19.900000
# Avg price per room      3.411039
# Name: 15, dtype: float64
# 16 CRIM                    1.053930
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      5.935000
# AGE                    29.300000
# DIS                     4.498600
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     386.850000
# LSTAT                   6.580000
# MEDV                   23.100000
# Avg price per room      3.892165
# Name: 16, dtype: float64
# 17 CRIM                    0.784200
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      5.990000
# AGE                    81.700000
# DIS                     4.257900
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     386.750000
# LSTAT                  14.670000
# MEDV                   17.500000
# Avg price per room      2.921536
# Name: 17, dtype: float64
# 18 CRIM                    0.802710
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      5.456000
# AGE                    36.600000
# DIS                     3.796500
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     288.990000
# LSTAT                  11.690000
# MEDV                   20.200000
# Avg price per room      3.702346
# Name: 18, dtype: float64
# 19 CRIM                    0.725800
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      5.727000
# AGE                    69.500000
# DIS                     3.796500
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     390.950000
# LSTAT                  11.280000
# MEDV                   18.200000
# Avg price per room      3.177929
# Name: 19, dtype: float64
# 20 CRIM                    1.251790
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      5.570000
# AGE                    98.100000
# DIS                     3.797900
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     376.570000
# LSTAT                  21.020000
# MEDV                   13.600000
# Avg price per room      2.441652
# Name: 20, dtype: float64
# 21 CRIM                    0.852040
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      5.965000
# AGE                    89.200000
# DIS                     4.012300
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     392.530000
# LSTAT                  13.830000
# MEDV                   19.600000
# Avg price per room      3.285834
# Name: 21, dtype: float64
# 22 CRIM                    1.232470
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      6.142000
# AGE                    91.700000
# DIS                     3.976900
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     396.900000
# LSTAT                  18.720000
# MEDV                   15.200000
# Avg price per room      2.474764
# Name: 22, dtype: float64
# 23 CRIM                    0.988430
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      5.813000
# AGE                   100.000000
# DIS                     4.095200
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     394.540000
# LSTAT                  19.880000
# MEDV                   14.500000
# Avg price per room      2.494409
# Name: 23, dtype: float64
# 24 CRIM                    0.750260
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      5.924000
# AGE                    94.100000
# DIS                     4.399600
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     394.330000
# LSTAT                  16.300000
# MEDV                   15.600000
# Avg price per room      2.633356
# Name: 24, dtype: float64
# 25 CRIM                    0.840540
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      5.599000
# AGE                    85.700000
# DIS                     4.454600
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     303.420000
# LSTAT                  16.510000
# MEDV                   13.900000
# Avg price per room      2.482586
# Name: 25, dtype: float64
# 26 CRIM                    0.671910
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      5.813000
# AGE                    90.300000
# DIS                     4.682000
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     376.880000
# LSTAT                  14.810000
# MEDV                   16.600000
# Avg price per room      2.855668
# Name: 26, dtype: float64
# 27 CRIM                    0.955770
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      6.047000
# AGE                    88.800000
# DIS                     4.453400
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     306.380000
# LSTAT                  17.280000
# MEDV                   14.800000
# Avg price per room      2.447495
# Name: 27, dtype: float64
# 28 CRIM                    0.772990
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      6.495000
# AGE                    94.400000
# DIS                     4.454700
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     387.940000
# LSTAT                  12.800000
# MEDV                   18.400000
# Avg price per room      2.832948
# Name: 28, dtype: float64
# 29 CRIM                    1.002450
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      6.674000
# AGE                    87.300000
# DIS                     4.239000
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     380.230000
# LSTAT                  11.980000
# MEDV                   21.000000
# Avg price per room      3.146539
# Name: 29, dtype: float64
# 30 CRIM                    1.13081
# ZN                      0.00000
# INDUS                   8.14000
# CHAS                    0.00000
# NOX                     0.53800
# RM                      5.71300
# AGE                    94.10000
# DIS                     4.23300
# RAD                     4.00000
# TAX                   307.00000
# PTRATIO                21.00000
# B                     360.17000
# LSTAT                  22.60000
# MEDV                   12.70000
# Avg price per room      2.22300
# Name: 30, dtype: float64
# 31 CRIM                    1.354720
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      6.072000
# AGE                   100.000000
# DIS                     4.175000
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     376.730000
# LSTAT                  13.040000
# MEDV                   14.500000
# Avg price per room      2.388011
# Name: 31, dtype: float64
# 32 CRIM                    1.387990
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      5.950000
# AGE                    82.000000
# DIS                     3.990000
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     232.600000
# LSTAT                  27.710000
# MEDV                   13.200000
# Avg price per room      2.218487
# Name: 32, dtype: float64
# 33 CRIM                    1.151720
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      5.701000
# AGE                    95.000000
# DIS                     3.787200
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     358.770000
# LSTAT                  18.350000
# MEDV                   13.100000
# Avg price per room      2.297842
# Name: 33, dtype: float64
# 34 CRIM                    1.612820
# ZN                      0.000000
# INDUS                   8.140000
# CHAS                    0.000000
# NOX                     0.538000
# RM                      6.096000
# AGE                    96.900000
# DIS                     3.759800
# RAD                     4.000000
# TAX                   307.000000
# PTRATIO                21.000000
# B                     248.310000
# LSTAT                  20.340000
# MEDV                   13.500000
# Avg price per room      2.214567
# Name: 34, dtype: float64
# 35 CRIM                    0.064170
# ZN                      0.000000
# INDUS                   5.960000
# CHAS                    0.000000
# NOX                     0.499000
# RM                      5.933000
# AGE                    68.200000
# DIS                     3.360300
# RAD                     5.000000
# TAX                   279.000000
# PTRATIO                19.200000
# B                     396.900000
# LSTAT                        NaN
# MEDV                   18.900000
# Avg price per room      3.185572
# Name: 35, dtype: float64
# 36 CRIM                    0.097440
# ZN                      0.000000
# INDUS                        NaN
# CHAS                    0.000000
# NOX                     0.499000
# RM                      5.841000
# AGE                    61.400000
# DIS                     3.377900
# RAD                     5.000000
# TAX                   279.000000
# PTRATIO                19.200000
# B                     377.560000
# LSTAT                  11.410000
# MEDV                   20.000000
# Avg price per room      3.424071
# Name: 36, dtype: float64
# 37 CRIM                    0.080140
# ZN                      0.000000
# INDUS                   5.960000
# CHAS                    0.000000
# NOX                     0.499000
# RM                      5.850000
# AGE                    41.500000
# DIS                     3.934200
# RAD                     5.000000
# TAX                   279.000000
# PTRATIO                19.200000
# B                     396.900000
# LSTAT                   8.770000
# MEDV                   21.000000
# Avg price per room      3.589744
# Name: 37, dtype: float64
# 38 CRIM                    0.175050
# ZN                      0.000000
# INDUS                   5.960000
# CHAS                    0.000000
# NOX                     0.499000
# RM                      5.966000
# AGE                    30.200000
# DIS                     3.847300
# RAD                     5.000000
# TAX                   279.000000
# PTRATIO                19.200000
# B                     393.430000
# LSTAT                  10.130000
# MEDV                   24.700000
# Avg price per room      4.140127
# Name: 38, dtype: float64
# 39 CRIM                    0.027630
# ZN                     75.000000
# INDUS                   2.950000
# CHAS                    0.000000
# NOX                     0.428000
# RM                      6.595000
# AGE                    21.800000
# DIS                     5.401100
# RAD                     3.000000
# TAX                   252.000000
# PTRATIO                18.300000
# B                     395.630000
# LSTAT                   4.320000
# MEDV                   30.800000
# Avg price per room      4.670205
# Name: 39, dtype: float64
# 40 CRIM                    0.033590
# ZN                     75.000000
# INDUS                   2.950000
# CHAS                    0.000000
# NOX                     0.428000
# RM                      7.024000
# AGE                    15.800000
# DIS                     5.401100
# RAD                     3.000000
# TAX                   252.000000
# PTRATIO                18.300000
# B                     395.620000
# LSTAT                   1.980000
# MEDV                   34.900000
# Avg price per room      4.968679
# Name: 40, dtype: float64
# 41 CRIM                    0.127440
# ZN                      0.000000
# INDUS                   6.910000
# CHAS                    0.000000
# NOX                     0.448000
# RM                      6.770000
# AGE                     2.900000
# DIS                     5.720900
# RAD                     3.000000
# TAX                   233.000000
# PTRATIO                17.900000
# B                     385.410000
# LSTAT                   4.840000
# MEDV                   26.600000
# Avg price per room      3.929099
# Name: 41, dtype: float64
# 42 CRIM                    0.141500
# ZN                      0.000000
# INDUS                   6.910000
# CHAS                    0.000000
# NOX                     0.448000
# RM                      6.169000
# AGE                     6.600000
# DIS                     5.720900
# RAD                     3.000000
# TAX                   233.000000
# PTRATIO                17.900000
# B                     383.370000
# LSTAT                   5.810000
# MEDV                   25.300000
# Avg price per room      4.101151
# Name: 42, dtype: float64
# 43 CRIM                    0.159360
# ZN                      0.000000
# INDUS                   6.910000
# CHAS                         NaN
# NOX                     0.448000
# RM                      6.211000
# AGE                     6.500000
# DIS                     5.720900
# RAD                     3.000000
# TAX                   233.000000
# PTRATIO                17.900000
# B                     394.460000
# LSTAT                   7.440000
# MEDV                   24.700000
# Avg price per room      3.976815
# Name: 43, dtype: float64
# 44 CRIM                    0.122690
# ZN                      0.000000
# INDUS                   6.910000
# CHAS                    0.000000
# NOX                     0.448000
# RM                      6.069000
# AGE                    40.000000
# DIS                     5.720900
# RAD                     3.000000
# TAX                   233.000000
# PTRATIO                17.900000
# B                     389.390000
# LSTAT                   9.550000
# MEDV                   21.200000
# Avg price per room      3.493162
# Name: 44, dtype: float64
# 45 CRIM                    0.171420
# ZN                      0.000000
# INDUS                   6.910000
# CHAS                    0.000000
# NOX                     0.448000
# RM                      5.682000
# AGE                    33.800000
# DIS                     5.100400
# RAD                     3.000000
# TAX                   233.000000
# PTRATIO                17.900000
# B                     396.900000
# LSTAT                  10.210000
# MEDV                   19.300000
# Avg price per room      3.396691
# Name: 45, dtype: float64
# 46 CRIM                    0.188360
# ZN                      0.000000
# INDUS                   6.910000
# CHAS                    0.000000
# NOX                     0.448000
# RM                      5.786000
# AGE                    33.300000
# DIS                     5.100400
# RAD                     3.000000
# TAX                   233.000000
# PTRATIO                17.900000
# B                     396.900000
# LSTAT                  14.150000
# MEDV                   20.000000
# Avg price per room      3.456619
# Name: 46, dtype: float64
# 47 CRIM                    0.229270
# ZN                      0.000000
# INDUS                        NaN
# CHAS                    0.000000
# NOX                     0.448000
# RM                      6.030000
# AGE                    85.500000
# DIS                     5.689400
# RAD                     3.000000
# TAX                   233.000000
# PTRATIO                17.900000
# B                     392.740000
# LSTAT                  18.800000
# MEDV                   16.600000
# Avg price per room      2.752902
# Name: 47, dtype: float64
# 48 CRIM                    0.253870
# ZN                      0.000000
# INDUS                   6.910000
# CHAS                    0.000000
# NOX                     0.448000
# RM                      5.399000
# AGE                    95.300000
# DIS                     5.870000
# RAD                     3.000000
# TAX                   233.000000
# PTRATIO                17.900000
# B                     396.900000
# LSTAT                  30.810000
# MEDV                   14.400000
# Avg price per room      2.667161
# Name: 48, dtype: float64
# 49 CRIM                    0.219770
# ZN                      0.000000
# INDUS                   6.910000
# CHAS                    0.000000
# NOX                     0.448000
# RM                      5.602000
# AGE                    62.000000
# DIS                     6.087700
# RAD                     3.000000
# TAX                   233.000000
# PTRATIO                17.900000
# B                     396.900000
# LSTAT                  16.200000
# MEDV                   19.400000
# Avg price per room      3.463049
# Name: 49, dtype: float64
# 50 CRIM                    0.088730
# ZN                     21.000000
# INDUS                   5.640000
# CHAS                    0.000000
# NOX                     0.439000
# RM                      5.963000
# AGE                    45.700000
# DIS                     6.814700
# RAD                     4.000000
# TAX                   243.000000
# PTRATIO                16.800000
# B                     395.560000
# LSTAT                  13.450000
# MEDV                   19.700000
# Avg price per room      3.303706
# Name: 50, dtype: float64
# 51 CRIM                    0.043370
# ZN                     21.000000
# INDUS                        NaN
# CHAS                    0.000000
# NOX                     0.439000
# RM                      6.115000
# AGE                    63.000000
# DIS                     6.814700
# RAD                     4.000000
# TAX                   243.000000
# PTRATIO                16.800000
# B                     393.970000
# LSTAT                   9.430000
# MEDV                   20.500000
# Avg price per room      3.352412
# Name: 51, dtype: float64
# 52 CRIM                    0.053600
# ZN                     21.000000
# INDUS                   5.640000
# CHAS                    0.000000
# NOX                     0.439000
# RM                      6.511000
# AGE                    21.100000
# DIS                     6.814700
# RAD                     4.000000
# TAX                   243.000000
# PTRATIO                16.800000
# B                     396.900000
# LSTAT                   5.280000
# MEDV                   25.000000
# Avg price per room      3.839656
# Name: 52, dtype: float64
# 53 CRIM                       NaN
# ZN                     21.0000
# INDUS                   5.6400
# CHAS                    0.0000
# NOX                     0.4390
# RM                      5.9980
# AGE                    21.4000
# DIS                     6.8147
# RAD                     4.0000
# TAX                   243.0000
# PTRATIO                16.8000
# B                     396.9000
# LSTAT                   8.4300
# MEDV                   23.4000
# Avg price per room      3.9013
# Name: 53, dtype: float64
# 54 CRIM                    0.013600
# ZN                     75.000000
# INDUS                   4.000000
# CHAS                    0.000000
# NOX                     0.410000
# RM                      5.888000
# AGE                    47.600000
# DIS                     7.319700
# RAD                     3.000000
# TAX                   469.000000
# PTRATIO                21.100000
# B                     396.900000
# LSTAT                  14.800000
# MEDV                   18.900000
# Avg price per room      3.209918
# Name: 54, dtype: float64
# 55 CRIM                    0.013110
# ZN                     90.000000
# INDUS                   1.220000
# CHAS                    0.000000
# NOX                     0.403000
# RM                      7.249000
# AGE                    21.900000
# DIS                     8.696600
# RAD                     5.000000
# TAX                   226.000000
# PTRATIO                17.900000
# B                     395.930000
# LSTAT                   4.810000
# MEDV                   35.400000
# Avg price per room      4.883432
# Name: 55, dtype: float64
# 56 CRIM                    0.020550
# ZN                     85.000000
# INDUS                   0.740000
# CHAS                    0.000000
# NOX                     0.410000
# RM                      6.383000
# AGE                    35.700000
# DIS                     9.187600
# RAD                     2.000000
# TAX                   313.000000
# PTRATIO                17.300000
# B                     396.900000
# LSTAT                   5.770000
# MEDV                   24.700000
# Avg price per room      3.869654
# Name: 56, dtype: float64
# 57 CRIM                    0.01432
# ZN                    100.00000
# INDUS                   1.32000
# CHAS                    0.00000
# NOX                     0.41100
# RM                      6.81600
# AGE                    40.50000
# DIS                     8.32480
# RAD                     5.00000
# TAX                   256.00000
# PTRATIO                15.10000
# B                     392.90000
# LSTAT                   3.95000
# MEDV                   31.60000
# Avg price per room      4.63615
# Name: 57, dtype: float64
# 58 CRIM                    0.154450
# ZN                     25.000000
# INDUS                   5.130000
# CHAS                    0.000000
# NOX                     0.453000
# RM                      6.145000
# AGE                    29.200000
# DIS                     7.814800
# RAD                     8.000000
# TAX                   284.000000
# PTRATIO                19.700000
# B                     390.680000
# LSTAT                   6.860000
# MEDV                   23.300000
# Avg price per room      3.791701
# Name: 58, dtype: float64
# 59 CRIM                    0.103280
# ZN                     25.000000
# INDUS                   5.130000
# CHAS                    0.000000
# NOX                     0.453000
# RM                      5.927000
# AGE                    47.200000
# DIS                     6.932000
# RAD                     8.000000
# TAX                   284.000000
# PTRATIO                19.700000
# B                     396.900000
# LSTAT                   9.220000
# MEDV                   19.600000
# Avg price per room      3.306901
# Name: 59, dtype: float64
# 60 CRIM                    0.149320
# ZN                     25.000000
# INDUS                   5.130000
# CHAS                    0.000000
# NOX                     0.453000
# RM                      5.741000
# AGE                    66.200000
# DIS                     7.225400
# RAD                     8.000000
# TAX                   284.000000
# PTRATIO                19.700000
# B                     395.110000
# LSTAT                  13.150000
# MEDV                   18.700000
# Avg price per room      3.257272
# Name: 60, dtype: float64
# 61 CRIM                    0.171710
# ZN                     25.000000
# INDUS                   5.130000
# CHAS                    0.000000
# NOX                     0.453000
# RM                      5.966000
# AGE                    93.400000
# DIS                     6.818500
# RAD                     8.000000
# TAX                   284.000000
# PTRATIO                19.700000
# B                     378.080000
# LSTAT                  14.440000
# MEDV                   16.000000
# Avg price per room      2.681864
# Name: 61, dtype: float64
# 62 CRIM                    0.110270
# ZN                     25.000000
# INDUS                   5.130000
# CHAS                    0.000000
# NOX                     0.453000
# RM                      6.456000
# AGE                    67.800000
# DIS                     7.225500
# RAD                     8.000000
# TAX                   284.000000
# PTRATIO                19.700000
# B                     396.900000
# LSTAT                   6.730000
# MEDV                   22.200000
# Avg price per room      3.438662
# Name: 62, dtype: float64
# 63 CRIM                    0.126500
# ZN                     25.000000
# INDUS                   5.130000
# CHAS                    0.000000
# NOX                     0.453000
# RM                      6.762000
# AGE                    43.400000
# DIS                     7.980900
# RAD                     8.000000
# TAX                   284.000000
# PTRATIO                19.700000
# B                     395.580000
# LSTAT                   9.500000
# MEDV                   25.000000
# Avg price per room      3.697131
# Name: 63, dtype: float64
# 64 CRIM                    0.01951
# ZN                     17.50000
# INDUS                   1.38000
# CHAS                    0.00000
# NOX                     0.41610
# RM                      7.10400
# AGE                    59.50000
# DIS                     9.22290
# RAD                     3.00000
# TAX                   216.00000
# PTRATIO                18.60000
# B                     393.24000
# LSTAT                   8.05000
# MEDV                   33.00000
# Avg price per room      4.64527
# Name: 64, dtype: float64
# 65 CRIM                    0.035840
# ZN                     80.000000
# INDUS                   3.370000
# CHAS                    0.000000
# NOX                     0.398000
# RM                      6.290000
# AGE                    17.800000
# DIS                     6.611500
# RAD                     4.000000
# TAX                   337.000000
# PTRATIO                16.100000
# B                     396.900000
# LSTAT                   4.670000
# MEDV                   23.500000
# Avg price per room      3.736089
# Name: 65, dtype: float64
# 66 CRIM                    0.043790
# ZN                     80.000000
# INDUS                   3.370000
# CHAS                    0.000000
# NOX                     0.398000
# RM                      5.787000
# AGE                    31.100000
# DIS                     6.611500
# RAD                     4.000000
# TAX                   337.000000
# PTRATIO                16.100000
# B                     396.900000
# LSTAT                  10.240000
# MEDV                   19.400000
# Avg price per room      3.352341
# Name: 66, dtype: float64
# 67 CRIM                    0.05789
# ZN                     12.50000
# INDUS                   6.07000
# CHAS                    0.00000
# NOX                     0.40900
# RM                      5.87800
# AGE                    21.40000
# DIS                     6.49800
# RAD                     4.00000
# TAX                   345.00000
# PTRATIO                18.90000
# B                     396.21000
# LSTAT                   8.10000
# MEDV                   22.00000
# Avg price per room      3.74277
# Name: 67, dtype: float64
# 68 CRIM                    0.135540
# ZN                     12.500000
# INDUS                   6.070000
# CHAS                    0.000000
# NOX                     0.409000
# RM                      5.594000
# AGE                    36.800000
# DIS                     6.498000
# RAD                     4.000000
# TAX                   345.000000
# PTRATIO                18.900000
# B                     396.900000
# LSTAT                  13.090000
# MEDV                   17.400000
# Avg price per room      3.110476
# Name: 68, dtype: float64
# 69 CRIM                    0.128160
# ZN                     12.500000
# INDUS                   6.070000
# CHAS                    0.000000
# NOX                     0.409000
# RM                      5.885000
# AGE                    33.000000
# DIS                     6.498000
# RAD                     4.000000
# TAX                   345.000000
# PTRATIO                18.900000
# B                     396.900000
# LSTAT                   8.790000
# MEDV                   20.900000
# Avg price per room      3.551402
# Name: 69, dtype: float64
# 70 CRIM                    0.088260
# ZN                      0.000000
# INDUS                  10.810000
# CHAS                    0.000000
# NOX                     0.413000
# RM                      6.417000
# AGE                     6.600000
# DIS                     5.287300
# RAD                     4.000000
# TAX                   305.000000
# PTRATIO                19.200000
# B                     383.730000
# LSTAT                   6.720000
# MEDV                   24.200000
# Avg price per room      3.771233
# Name: 70, dtype: float64
# 71 CRIM                    0.158760
# ZN                      0.000000
# INDUS                  10.810000
# CHAS                    0.000000
# NOX                     0.413000
# RM                      5.961000
# AGE                    17.500000
# DIS                     5.287300
# RAD                     4.000000
# TAX                   305.000000
# PTRATIO                19.200000
# B                     376.940000
# LSTAT                   9.880000
# MEDV                   21.700000
# Avg price per room      3.640329
# Name: 71, dtype: float64
# 72 CRIM                    0.091640
# ZN                      0.000000
# INDUS                  10.810000
# CHAS                    0.000000
# NOX                     0.413000
# RM                      6.065000
# AGE                     7.800000
# DIS                     5.287300
# RAD                     4.000000
# TAX                   305.000000
# PTRATIO                19.200000
# B                     390.910000
# LSTAT                   5.520000
# MEDV                   22.800000
# Avg price per room      3.759275
# Name: 72, dtype: float64
# 73 CRIM                    0.195390
# ZN                      0.000000
# INDUS                  10.810000
# CHAS                    0.000000
# NOX                     0.413000
# RM                      6.245000
# AGE                     6.200000
# DIS                     5.287300
# RAD                     4.000000
# TAX                   305.000000
# PTRATIO                19.200000
# B                     377.170000
# LSTAT                        NaN
# MEDV                   23.400000
# Avg price per room      3.746998
# Name: 73, dtype: float64
# 74 CRIM                    0.078960
# ZN                      0.000000
# INDUS                  12.830000
# CHAS                    0.000000
# NOX                     0.437000
# RM                      6.273000
# AGE                          NaN
# DIS                     4.251500
# RAD                     5.000000
# TAX                   398.000000
# PTRATIO                18.700000
# B                     394.920000
# LSTAT                   6.780000
# MEDV                   24.100000
# Avg price per room      3.841862
# Name: 74, dtype: float64
# 75 CRIM                    0.095120
# ZN                      0.000000
# INDUS                  12.830000
# CHAS                    0.000000
# NOX                     0.437000
# RM                      6.286000
# AGE                    45.000000
# DIS                     4.502600
# RAD                     5.000000
# TAX                   398.000000
# PTRATIO                18.700000
# B                     383.230000
# LSTAT                   8.940000
# MEDV                   21.400000
# Avg price per room      3.404391
# Name: 75, dtype: float64
# 76 CRIM                    0.101530
# ZN                      0.000000
# INDUS                  12.830000
# CHAS                    0.000000
# NOX                     0.437000
# RM                      6.279000
# AGE                    74.500000
# DIS                     4.052200
# RAD                     5.000000
# TAX                   398.000000
# PTRATIO                18.700000
# B                     373.660000
# LSTAT                  11.970000
# MEDV                   20.000000
# Avg price per room      3.185221
# Name: 76, dtype: float64
# 77 CRIM                    0.087070
# ZN                      0.000000
# INDUS                  12.830000
# CHAS                    0.000000
# NOX                     0.437000
# RM                      6.140000
# AGE                    45.800000
# DIS                     4.090500
# RAD                     5.000000
# TAX                   398.000000
# PTRATIO                18.700000
# B                     386.960000
# LSTAT                  10.270000
# MEDV                   20.800000
# Avg price per room      3.387622
# Name: 77, dtype: float64
# 78 CRIM                    0.056460
# ZN                      0.000000
# INDUS                  12.830000
# CHAS                    0.000000
# NOX                     0.437000
# RM                      6.232000
# AGE                    53.700000
# DIS                     5.014100
# RAD                     5.000000
# TAX                   398.000000
# PTRATIO                18.700000
# B                     386.400000
# LSTAT                  12.340000
# MEDV                   21.200000
# Avg price per room      3.401797
# Name: 78, dtype: float64
# 79 CRIM                    0.083870
# ZN                      0.000000
# INDUS                  12.830000
# CHAS                    0.000000
# NOX                     0.437000
# RM                      5.874000
# AGE                    36.600000
# DIS                     4.502600
# RAD                     5.000000
# TAX                   398.000000
# PTRATIO                18.700000
# B                     396.060000
# LSTAT                        NaN
# MEDV                   20.300000
# Avg price per room      3.455907
# Name: 79, dtype: float64
# 80 CRIM                    0.041130
# ZN                     25.000000
# INDUS                   4.860000
# CHAS                    0.000000
# NOX                     0.426000
# RM                      6.727000
# AGE                    33.500000
# DIS                     5.400700
# RAD                     4.000000
# TAX                   281.000000
# PTRATIO                19.000000
# B                     396.900000
# LSTAT                   5.290000
# MEDV                   28.000000
# Avg price per room      4.162331
# Name: 80, dtype: float64
# 81 CRIM                    0.044620
# ZN                     25.000000
# INDUS                   4.860000
# CHAS                    0.000000
# NOX                     0.426000
# RM                      6.619000
# AGE                    70.400000
# DIS                     5.400700
# RAD                     4.000000
# TAX                   281.000000
# PTRATIO                19.000000
# B                     395.630000
# LSTAT                   7.220000
# MEDV                   23.900000
# Avg price per room      3.610817
# Name: 81, dtype: float64
# 82 CRIM                    0.036590
# ZN                     25.000000
# INDUS                   4.860000
# CHAS                    0.000000
# NOX                     0.426000
# RM                      6.302000
# AGE                    32.200000
# DIS                     5.400700
# RAD                     4.000000
# TAX                   281.000000
# PTRATIO                19.000000
# B                     396.900000
# LSTAT                   6.720000
# MEDV                   24.800000
# Avg price per room      3.935259
# Name: 82, dtype: float64
# 83 CRIM                    0.035510
# ZN                     25.000000
# INDUS                   4.860000
# CHAS                    0.000000
# NOX                     0.426000
# RM                      6.167000
# AGE                    46.700000
# DIS                     5.400700
# RAD                     4.000000
# TAX                   281.000000
# PTRATIO                19.000000
# B                     390.640000
# LSTAT                   7.510000
# MEDV                   22.900000
# Avg price per room      3.713313
# Name: 83, dtype: float64
# 84 CRIM                    0.050590
# ZN                      0.000000
# INDUS                   4.490000
# CHAS                    0.000000
# NOX                     0.449000
# RM                      6.389000
# AGE                    48.000000
# DIS                     4.779400
# RAD                     3.000000
# TAX                   247.000000
# PTRATIO                18.500000
# B                     396.900000
# LSTAT                   9.620000
# MEDV                   23.900000
# Avg price per room      3.740805
# Name: 84, dtype: float64
# 85 CRIM                    0.057350
# ZN                      0.000000
# INDUS                   4.490000
# CHAS                    0.000000
# NOX                     0.449000
# RM                      6.630000
# AGE                    56.100000
# DIS                     4.437700
# RAD                     3.000000
# TAX                   247.000000
# PTRATIO                18.500000
# B                     392.300000
# LSTAT                   6.530000
# MEDV                   26.600000
# Avg price per room      4.012066
# Name: 85, dtype: float64
# 86 CRIM                    0.051880
# ZN                      0.000000
# INDUS                   4.490000
# CHAS                    0.000000
# NOX                     0.449000
# RM                      6.015000
# AGE                    45.100000
# DIS                     4.427200
# RAD                     3.000000
# TAX                   247.000000
# PTRATIO                18.500000
# B                     395.990000
# LSTAT                  12.860000
# MEDV                   22.500000
# Avg price per room      3.740648
# Name: 86, dtype: float64
# 87 CRIM                    0.071510
# ZN                      0.000000
# INDUS                   4.490000
# CHAS                    0.000000
# NOX                     0.449000
# RM                      6.121000
# AGE                    56.800000
# DIS                     3.747600
# RAD                     3.000000
# TAX                   247.000000
# PTRATIO                18.500000
# B                     395.150000
# LSTAT                        NaN
# MEDV                   22.200000
# Avg price per room      3.626858
# Name: 87, dtype: float64
# 88 CRIM                    0.056600
# ZN                      0.000000
# INDUS                   3.410000
# CHAS                    0.000000
# NOX                     0.489000
# RM                      7.007000
# AGE                    86.300000
# DIS                     3.421700
# RAD                     2.000000
# TAX                   270.000000
# PTRATIO                17.800000
# B                     396.900000
# LSTAT                   5.500000
# MEDV                   23.600000
# Avg price per room      3.368061
# Name: 88, dtype: float64
# 89 CRIM                    0.053020
# ZN                      0.000000
# INDUS                   3.410000
# CHAS                    0.000000
# NOX                     0.489000
# RM                      7.079000
# AGE                    63.100000
# DIS                     3.414500
# RAD                     2.000000
# TAX                   270.000000
# PTRATIO                17.800000
# B                     396.060000
# LSTAT                   5.700000
# MEDV                   28.700000
# Avg price per room      4.054245
# Name: 89, dtype: float64
# 90 CRIM                    0.046840
# ZN                      0.000000
# INDUS                   3.410000
# CHAS                    0.000000
# NOX                     0.489000
# RM                      6.417000
# AGE                    66.100000
# DIS                     3.092300
# RAD                     2.000000
# TAX                   270.000000
# PTRATIO                17.800000
# B                     392.180000
# LSTAT                   8.810000
# MEDV                   22.600000
# Avg price per room      3.521895
# Name: 90, dtype: float64
# 91 CRIM                    0.039320
# ZN                      0.000000
# INDUS                   3.410000
# CHAS                    0.000000
# NOX                     0.489000
# RM                      6.405000
# AGE                    73.900000
# DIS                     3.092100
# RAD                     2.000000
# TAX                   270.000000
# PTRATIO                17.800000
# B                     393.550000
# LSTAT                   8.200000
# MEDV                   22.000000
# Avg price per room      3.434817
# Name: 91, dtype: float64
# ...
# DIS                     2.20600
# RAD                    24.00000
# TAX                   666.00000
# PTRATIO                20.20000
# B                     302.76000
# LSTAT                  24.10000
# MEDV                   13.30000
# Avg price per room      2.15839
# Name: 475, dtype: float64
# 476 CRIM                    4.871410
# ZN                      0.000000
# INDUS                  18.100000
# CHAS                    0.000000
# NOX                     0.614000
# RM                      6.484000
# AGE                    93.600000
# DIS                     2.305300
# RAD                    24.000000
# TAX                   666.000000
# PTRATIO                20.200000
# B                     396.210000
# LSTAT                  18.680000
# MEDV                   16.700000
# Avg price per room      2.575571
# Name: 476, dtype: float64
# 477 CRIM                   15.023400
# ZN                      0.000000
# INDUS                  18.100000
# CHAS                    0.000000
# NOX                     0.614000
# RM                      5.304000
# AGE                    97.300000
# DIS                     2.100700
# RAD                    24.000000
# TAX                   666.000000
# PTRATIO                20.200000
# B                     349.480000
# LSTAT                  24.910000
# MEDV                   12.000000
# Avg price per room      2.262443
# Name: 477, dtype: float64
# 478 CRIM                   10.23300
# ZN                      0.00000
# INDUS                  18.10000
# CHAS                    0.00000
# NOX                     0.61400
# RM                      6.18500
# AGE                    96.70000
# DIS                     2.17050
# RAD                    24.00000
# TAX                   666.00000
# PTRATIO                20.20000
# B                     379.70000
# LSTAT                  18.03000
# MEDV                   14.60000
# Avg price per room      2.36055
# Name: 478, dtype: float64
# 479 CRIM                   14.333700
# ZN                      0.000000
# INDUS                  18.100000
# CHAS                         NaN
# NOX                     0.614000
# RM                      6.229000
# AGE                    88.000000
# DIS                     1.951200
# RAD                    24.000000
# TAX                   666.000000
# PTRATIO                20.200000
# B                     383.320000
# LSTAT                  13.110000
# MEDV                   21.400000
# Avg price per room      3.435543
# Name: 479, dtype: float64
# 480 CRIM                    5.824010
# ZN                      0.000000
# INDUS                  18.100000
# CHAS                    0.000000
# NOX                     0.532000
# RM                      6.242000
# AGE                    64.700000
# DIS                     3.424200
# RAD                    24.000000
# TAX                   666.000000
# PTRATIO                20.200000
# B                     396.900000
# LSTAT                  10.740000
# MEDV                   23.000000
# Avg price per room      3.684716
# Name: 480, dtype: float64
# 481 CRIM                    5.708180
# ZN                      0.000000
# INDUS                  18.100000
# CHAS                    0.000000
# NOX                     0.532000
# RM                      6.750000
# AGE                    74.900000
# DIS                     3.331700
# RAD                    24.000000
# TAX                   666.000000
# PTRATIO                20.200000
# B                     393.070000
# LSTAT                   7.740000
# MEDV                   23.700000
# Avg price per room      3.511111
# Name: 481, dtype: float64
# 482 CRIM                    5.731160
# ZN                      0.000000
# INDUS                  18.100000
# CHAS                         NaN
# NOX                     0.532000
# RM                      7.061000
# AGE                    77.000000
# DIS                     3.410600
# RAD                    24.000000
# TAX                   666.000000
# PTRATIO                20.200000
# B                     395.280000
# LSTAT                   7.010000
# MEDV                   25.000000
# Avg price per room      3.540575
# Name: 482, dtype: float64
# 483 CRIM                    2.818380
# ZN                      0.000000
# INDUS                  18.100000
# CHAS                    0.000000
# NOX                     0.532000
# RM                      5.762000
# AGE                    40.300000
# DIS                     4.098300
# RAD                    24.000000
# TAX                   666.000000
# PTRATIO                20.200000
# B                     392.920000
# LSTAT                  10.420000
# MEDV                   21.800000
# Avg price per room      3.783409
# Name: 483, dtype: float64
# 484 CRIM                    2.378570
# ZN                      0.000000
# INDUS                  18.100000
# CHAS                    0.000000
# NOX                     0.583000
# RM                      5.871000
# AGE                    41.900000
# DIS                     3.724000
# RAD                    24.000000
# TAX                   666.000000
# PTRATIO                20.200000
# B                     370.730000
# LSTAT                  13.340000
# MEDV                   20.600000
# Avg price per room      3.508772
# Name: 484, dtype: float64
# 485 CRIM                    3.673670
# ZN                      0.000000
# INDUS                  18.100000
# CHAS                    0.000000
# NOX                     0.583000
# RM                      6.312000
# AGE                    51.900000
# DIS                     3.991700
# RAD                    24.000000
# TAX                   666.000000
# PTRATIO                20.200000
# B                     388.620000
# LSTAT                  10.580000
# MEDV                   21.200000
# Avg price per room      3.358682
# Name: 485, dtype: float64
# 486 CRIM                    5.691750
# ZN                      0.000000
# INDUS                  18.100000
# CHAS                    0.000000
# NOX                     0.583000
# RM                      6.114000
# AGE                    79.800000
# DIS                     3.545900
# RAD                    24.000000
# TAX                   666.000000
# PTRATIO                20.200000
# B                     392.680000
# LSTAT                  14.980000
# MEDV                   19.100000
# Avg price per room      3.123978
# Name: 486, dtype: float64
# 487 CRIM                    4.835670
# ZN                      0.000000
# INDUS                  18.100000
# CHAS                    0.000000
# NOX                     0.583000
# RM                      5.905000
# AGE                    53.200000
# DIS                     3.152300
# RAD                    24.000000
# TAX                   666.000000
# PTRATIO                20.200000
# B                     388.220000
# LSTAT                  11.450000
# MEDV                   20.600000
# Avg price per room      3.488569
# Name: 487, dtype: float64
# 488 CRIM                    0.150860
# ZN                      0.000000
# INDUS                  27.740000
# CHAS                    0.000000
# NOX                     0.609000
# RM                      5.454000
# AGE                    92.700000
# DIS                     1.820900
# RAD                     4.000000
# TAX                   711.000000
# PTRATIO                20.100000
# B                     395.090000
# LSTAT                  18.060000
# MEDV                   15.200000
# Avg price per room      2.786945
# Name: 488, dtype: float64
# 489 CRIM                    0.183370
# ZN                      0.000000
# INDUS                  27.740000
# CHAS                    0.000000
# NOX                     0.609000
# RM                      5.414000
# AGE                    98.300000
# DIS                     1.755400
# RAD                     4.000000
# TAX                   711.000000
# PTRATIO                20.100000
# B                     344.050000
# LSTAT                  23.970000
# MEDV                    7.000000
# Avg price per room      1.292944
# Name: 489, dtype: float64
# 490 CRIM                    0.207460
# ZN                      0.000000
# INDUS                  27.740000
# CHAS                    0.000000
# NOX                     0.609000
# RM                      5.093000
# AGE                    98.000000
# DIS                     1.822600
# RAD                     4.000000
# TAX                   711.000000
# PTRATIO                20.100000
# B                     318.430000
# LSTAT                  29.680000
# MEDV                    8.100000
# Avg price per room      1.590418
# Name: 490, dtype: float64
# 491 CRIM                    0.105740
# ZN                      0.000000
# INDUS                  27.740000
# CHAS                    0.000000
# NOX                     0.609000
# RM                      5.983000
# AGE                    98.800000
# DIS                     1.868100
# RAD                     4.000000
# TAX                   711.000000
# PTRATIO                20.100000
# B                     390.110000
# LSTAT                  18.070000
# MEDV                   13.600000
# Avg price per room      2.273107
# Name: 491, dtype: float64
# 492 CRIM                    0.111320
# ZN                      0.000000
# INDUS                  27.740000
# CHAS                    0.000000
# NOX                     0.609000
# RM                      5.983000
# AGE                    83.500000
# DIS                     2.109900
# RAD                     4.000000
# TAX                   711.000000
# PTRATIO                20.100000
# B                     396.900000
# LSTAT                  13.350000
# MEDV                   20.100000
# Avg price per room      3.359519
# Name: 492, dtype: float64
# 493 CRIM                    0.17331
# ZN                      0.00000
# INDUS                   9.69000
# CHAS                    0.00000
# NOX                     0.58500
# RM                      5.70700
# AGE                    54.00000
# DIS                     2.38170
# RAD                     6.00000
# TAX                   391.00000
# PTRATIO                19.20000
# B                     396.90000
# LSTAT                  12.01000
# MEDV                   21.80000
# Avg price per room      3.81987
# Name: 493, dtype: float64
# 494 CRIM                    0.279570
# ZN                      0.000000
# INDUS                   9.690000
# CHAS                    0.000000
# NOX                     0.585000
# RM                      5.926000
# AGE                    42.600000
# DIS                     2.381700
# RAD                     6.000000
# TAX                   391.000000
# PTRATIO                19.200000
# B                     396.900000
# LSTAT                  13.590000
# MEDV                   24.500000
# Avg price per room      4.134323
# Name: 494, dtype: float64
# 495 CRIM                    0.178990
# ZN                      0.000000
# INDUS                   9.690000
# CHAS                    0.000000
# NOX                     0.585000
# RM                      5.670000
# AGE                    28.800000
# DIS                     2.798600
# RAD                     6.000000
# TAX                   391.000000
# PTRATIO                19.200000
# B                     393.290000
# LSTAT                  17.600000
# MEDV                   23.100000
# Avg price per room      4.074074
# Name: 495, dtype: float64
# 496 CRIM                    0.289600
# ZN                      0.000000
# INDUS                   9.690000
# CHAS                    0.000000
# NOX                     0.585000
# RM                      5.390000
# AGE                    72.900000
# DIS                     2.798600
# RAD                     6.000000
# TAX                   391.000000
# PTRATIO                19.200000
# B                     396.900000
# LSTAT                  21.140000
# MEDV                   19.700000
# Avg price per room      3.654917
# Name: 496, dtype: float64
# 497 CRIM                    0.26838
# ZN                      0.00000
# INDUS                   9.69000
# CHAS                    0.00000
# NOX                     0.58500
# RM                      5.79400
# AGE                    70.60000
# DIS                     2.89270
# RAD                     6.00000
# TAX                   391.00000
# PTRATIO                19.20000
# B                     396.90000
# LSTAT                  14.10000
# MEDV                   18.30000
# Avg price per room      3.15844
# Name: 497, dtype: float64
# 498 CRIM                    0.23912
# ZN                      0.00000
# INDUS                   9.69000
# CHAS                    0.00000
# NOX                     0.58500
# RM                      6.01900
# AGE                    65.30000
# DIS                     2.40910
# RAD                     6.00000
# TAX                   391.00000
# PTRATIO                19.20000
# B                     396.90000
# LSTAT                  12.92000
# MEDV                   21.20000
# Avg price per room      3.52218
# Name: 498, dtype: float64
# 499 CRIM                    0.177830
# ZN                      0.000000
# INDUS                   9.690000
# CHAS                    0.000000
# NOX                     0.585000
# RM                      5.569000
# AGE                    73.500000
# DIS                     2.399900
# RAD                     6.000000
# TAX                   391.000000
# PTRATIO                19.200000
# B                     395.770000
# LSTAT                  15.100000
# MEDV                   17.500000
# Avg price per room      3.142395
# Name: 499, dtype: float64
# 500 CRIM                    0.224380
# ZN                      0.000000
# INDUS                   9.690000
# CHAS                    0.000000
# NOX                     0.585000
# RM                      6.027000
# AGE                    79.700000
# DIS                     2.498200
# RAD                     6.000000
# TAX                   391.000000
# PTRATIO                19.200000
# B                     396.900000
# LSTAT                  14.330000
# MEDV                   16.800000
# Avg price per room      2.787456
# Name: 500, dtype: float64
# 501 CRIM                    0.062630
# ZN                      0.000000
# INDUS                  11.930000
# CHAS                    0.000000
# NOX                     0.573000
# RM                      6.593000
# AGE                    69.100000
# DIS                     2.478600
# RAD                     1.000000
# TAX                   273.000000
# PTRATIO                21.000000
# B                     391.990000
# LSTAT                        NaN
# MEDV                   22.400000
# Avg price per room      3.397543
# Name: 501, dtype: float64
# 502 CRIM                    0.045270
# ZN                      0.000000
# INDUS                  11.930000
# CHAS                    0.000000
# NOX                     0.573000
# RM                      6.120000
# AGE                    76.700000
# DIS                     2.287500
# RAD                     1.000000
# TAX                   273.000000
# PTRATIO                21.000000
# B                     396.900000
# LSTAT                   9.080000
# MEDV                   20.600000
# Avg price per room      3.366013
# Name: 502, dtype: float64
# 503 CRIM                    0.060760
# ZN                      0.000000
# INDUS                  11.930000
# CHAS                    0.000000
# NOX                     0.573000
# RM                      6.976000
# AGE                    91.000000
# DIS                     2.167500
# RAD                     1.000000
# TAX                   273.000000
# PTRATIO                21.000000
# B                     396.900000
# LSTAT                   5.640000
# MEDV                   23.900000
# Avg price per room      3.426032
# Name: 503, dtype: float64
# 504 CRIM                    0.109590
# ZN                      0.000000
# INDUS                  11.930000
# CHAS                    0.000000
# NOX                     0.573000
# RM                      6.794000
# AGE                    89.300000
# DIS                     2.388900
# RAD                     1.000000
# TAX                   273.000000
# PTRATIO                21.000000
# B                     393.450000
# LSTAT                   6.480000
# MEDV                   22.000000
# Avg price per room      3.238151
# Name: 504, dtype: float64
# 505 CRIM                    0.047410
# ZN                      0.000000
# INDUS                  11.930000
# CHAS                    0.000000
# NOX                     0.573000
# RM                      6.030000
# AGE                          NaN
# DIS                     2.505000
# RAD                     1.000000
# TAX                   273.000000
# PTRATIO                21.000000
# B                     396.900000
# LSTAT                   7.880000
# MEDV                   11.900000
# Avg price per room      1.973466
# Name: 505, dtype: float64

# %% [markdown]
# ### **Selecting Columns while looping over dataframe**

# %%
for ind,row in boston.iterrows():
  print(row['MEDV'])
# Out:
# 24.0
# 21.6
# 34.7
# 33.4
# 36.2
# 28.7
# 22.9
# 27.1
# 16.5
# 18.9
# 15.0
# 18.9
# 21.7
# 20.4
# 18.2
# 19.9
# 23.1
# 17.5
# 20.2
# 18.2
# 13.6
# 19.6
# 15.2
# 14.5
# 15.6
# 13.9
# 16.6
# 14.8
# 18.4
# 21.0
# 12.7
# 14.5
# 13.2
# 13.1
# 13.5
# 18.9
# 20.0
# 21.0
# 24.7
# 30.8
# 34.9
# 26.6
# 25.3
# 24.7
# 21.2
# 19.3
# 20.0
# 16.6
# 14.4
# 19.4
# 19.7
# 20.5
# 25.0
# 23.4
# 18.9
# 35.4
# 24.7
# 31.6
# 23.3
# 19.6
# 18.7
# 16.0
# 22.2
# 25.0
# 33.0
# 23.5
# 19.4
# 22.0
# 17.4
# 20.9
# 24.2
# 21.7
# 22.8
# 23.4
# 24.1
# 21.4
# 20.0
# 20.8
# 21.2
# 20.3
# 28.0
# 23.9
# 24.8
# 22.9
# 23.9
# 26.6
# 22.5
# 22.2
# 23.6
# 28.7
# 22.6
# 22.0
# 22.9
# 25.0
# 20.6
# 28.4
# 21.4
# 38.7
# 43.8
# 33.2
# 27.5
# 26.5
# 18.6
# 19.3
# 20.1
# 19.5
# 19.5
# 20.4
# 19.8
# 19.4
# 21.7
# 22.8
# 18.8
# 18.7
# 18.5
# 18.3
# 21.2
# 19.2
# 20.4
# 19.3
# 22.0
# 20.3
# 20.5
# 17.3
# 18.8
# 21.4
# 15.7
# 16.2
# 18.0
# 14.3
# 19.2
# 19.6
# 23.0
# 18.4
# 15.6
# 18.1
# 17.4
# 17.1
# 13.3
# 17.8
# 14.0
# 14.4
# 13.4
# 15.6
# 11.8
# 13.8
# 15.6
# 14.6
# 17.8
# 15.4
# 21.5
# 19.6
# 15.3
# 19.4
# 17.0
# 15.6
# 13.1
# 41.3
# 24.3
# 23.3
# 27.0
# 50.0
# 50.0
# 50.0
# 22.7
# 25.0
# 50.0
# 23.8
# 23.8
# 22.3
# 17.4
# 19.1
# 23.1
# 23.6
# 22.6
# 29.4
# 23.2
# 24.6
# 29.9
# 37.2
# 39.8
# 36.2
# 37.9
# 32.5
# 26.4
# 29.6
# 50.0
# 32.0
# 29.8
# 34.9
# 37.0
# 30.5
# 36.4
# 31.1
# 29.1
# 50.0
# 33.3
# 30.3
# 34.6
# 34.9
# 32.9
# 24.1
# 42.3
# 48.5
# 50.0
# 22.6
# 24.4
# 22.5
# 24.4
# 20.0
# 21.7
# 19.3
# 22.4
# 28.1
# 23.7
# 25.0
# 23.3
# 28.7
# 21.5
# 23.0
# 26.7
# 21.7
# 27.5
# 30.1
# 44.8
# 50.0
# 37.6
# 31.6
# 46.7
# 31.5
# 24.3
# 31.7
# 41.7
# 48.3
# 29.0
# 24.0
# 25.1
# 31.5
# 23.7
# 23.3
# 22.0
# 20.1
# 22.2
# 23.7
# 17.6
# 18.5
# 24.3
# 20.5
# 24.5
# 26.2
# 24.4
# 24.8
# 29.6
# 42.8
# 21.9
# 20.9
# 44.0
# 50.0
# 36.0
# 30.1
# 33.8
# 43.1
# 48.8
# 31.0
# 36.5
# 22.8
# 30.7
# 50.0
# 43.5
# 20.7
# 21.1
# 25.2
# 24.4
# 35.2
# 32.4
# 32.0
# 33.2
# 33.1
# 29.1
# 35.1
# 45.4
# 35.4
# 46.0
# 50.0
# 32.2
# 22.0
# 20.1
# 23.2
# 22.3
# 24.8
# 28.5
# 37.3
# 27.9
# 23.9
# 21.7
# 28.6
# 27.1
# 20.3
# 22.5
# 29.0
# 24.8
# 22.0
# 26.4
# 33.1
# 36.1
# 28.4
# 33.4
# 28.2
# 22.8
# 20.3
# 16.1
# 22.1
# 19.4
# 21.6
# 23.8
# 16.2
# 17.8
# 19.8
# 23.1
# 21.0
# 23.8
# 23.1
# 20.4
# 18.5
# 25.0
# 24.6
# 23.0
# 22.2
# 19.3
# 22.6
# 19.8
# 17.1
# 19.4
# 22.2
# 20.7
# 21.1
# 19.5
# 18.5
# 20.6
# 19.0
# 18.7
# 32.7
# 16.5
# 23.9
# 31.2
# 17.5
# 17.2
# 23.1
# 24.5
# 26.6
# 22.9
# 24.1
# 18.6
# 30.1
# 18.2
# 20.6
# 17.8
# 21.7
# 22.7
# 22.6
# 25.0
# 19.9
# 20.8
# 16.8
# 21.9
# 27.5
# 21.9
# 23.1
# 50.0
# 50.0
# 50.0
# 50.0
# 50.0
# 13.8
# 13.8
# 15.0
# 13.9
# 13.3
# 13.1
# 10.2
# 10.4
# 10.9
# 11.3
# 12.3
# 8.8
# 7.2
# 10.5
# 7.4
# 10.2
# 11.5
# 15.1
# 23.2
# 9.7
# 13.8
# 12.7
# 13.1
# 12.5
# 8.5
# 5.0
# 6.3
# 5.6
# 7.2
# 12.1
# 8.3
# 8.5
# 5.0
# 11.9
# 27.9
# 17.2
# 27.5
# 15.0
# 17.2
# 17.9
# 16.3
# 7.0
# 7.2
# 7.5
# 10.4
# 8.8
# 8.4
# 16.7
# 14.2
# 20.8
# 13.4
# 11.7
# 8.3
# 10.2
# 10.9
# 11.0
# 9.5
# 14.5
# 14.1
# 16.1
# 14.3
# 11.7
# 13.4
# 9.6
# 8.7
# 8.4
# 12.8
# 10.5
# 17.1
# 18.4
# 15.4
# 10.8
# 11.8
# 14.9
# 12.6
# 14.1
# 13.0
# 13.4
# 15.2
# 16.1
# 17.8
# 14.9
# 14.1
# 12.7
# 13.5
# 14.9
# 20.0
# 16.4
# 17.7
# 19.5
# 20.2
# 21.4
# 19.9
# 19.0
# 19.1
# 19.1
# 20.1
# 19.9
# 19.6
# 23.2
# 29.8
# 13.8
# 13.3
# 16.7
# 12.0
# 14.6
# 21.4
# 23.0
# 23.7
# 25.0
# 21.8
# 20.6
# 21.2
# 19.1
# 20.6
# 15.2
# 7.0
# 8.1
# 13.6
# 20.1
# 21.8
# 24.5
# 23.1
# 19.7
# 18.3
# 21.2
# 17.5
# 16.8
# 22.4
# 20.6
# 23.9
# 22.0
# 11.9

# %%
for ind,row in boston.iterrows():
  print(row['RM'])
# Out:
# 6.575
# 6.421
# 7.185
# 6.997999999999999
# 7.147
# 6.43
# 6.0120000000000005
# 6.172000000000001
# 5.631
# 6.004
# 6.377000000000001
# 6.0089999999999995
# 5.888999999999999
# 5.949
# 6.096
# 5.834
# 5.935
# 5.99
# 5.456
# 5.727
# 5.57
# 5.965
# 6.142
# 5.813
# 5.9239999999999995
# 5.599
# 5.813
# 6.047000000000001
# 6.495
# 6.6739999999999995
# 5.712999999999999
# 6.072
# 5.95
# 5.7010000000000005
# 6.096
# 5.933
# 5.841
# 5.85
# 5.966
# 6.595
# 7.024
# 6.77
# 6.169
# 6.211
# 6.069
# 5.682
# 5.7860000000000005
# 6.03
# 5.399
# 5.602
# 5.962999999999999
# 6.115
# 6.511
# 5.997999999999999
# 5.888
# 7.249
# 6.382999999999999
# 6.816
# 6.145
# 5.9270000000000005
# 5.7410000000000005
# 5.966
# 6.456
# 6.7620000000000005
# 7.104
# 6.29
# 5.787000000000001
# 5.877999999999999
# 5.593999999999999
# 5.885
# 6.417000000000001
# 5.961
# 6.065
# 6.245
# 6.273
# 6.2860000000000005
# 6.279
# 6.14
# 6.232
# 5.874
# 6.727
# 6.619
# 6.3020000000000005
# 6.167000000000001
# 6.388999999999999
# 6.63
# 6.015
# 6.121
# 7.007000000000001
# 7.079
# 6.417000000000001
# 6.405
# 6.442
# 6.211
# 6.249
# 6.625
# 6.162999999999999
# 8.068999999999999
# 7.82
# 7.416
# 6.727
# 6.781000000000001
# 6.405
# 6.1370000000000005
# 6.167000000000001
# 5.851
# 5.836
# 6.127000000000001
# 6.474
# 6.229
# 6.195
# 6.715
# 5.912999999999999
# 6.0920000000000005
# 6.254
# 5.928
# 6.176
# 6.021
# 5.872000000000001
# 5.731
# 5.87
# 6.004
# 5.961
# 5.856
# 5.879
# 5.986000000000001
# 5.6129999999999995
# 5.693
# 6.431
# 5.6370000000000005
# 6.457999999999999
# 6.3260000000000005
# 6.372000000000001
# 5.822
# 5.757000000000001
# 6.335
# 5.942
# 6.454
# 5.857
# 6.151
# 6.1739999999999995
# 5.019
# 5.403
# 5.468
# 4.9030000000000005
# 6.13
# 5.627999999999999
# 4.926
# 5.186
# 5.597
# 6.122000000000001
# 5.404
# 5.012
# 5.709
# 6.129
# 6.152
# 5.272
# 6.943
# 6.066
# 6.51
# 6.25
# 7.489
# 7.8020000000000005
# 8.375
# 5.854
# 6.101
# 7.928999999999999
# 5.877000000000001
# 6.319
# 6.402
# 5.875
# 5.88
# 5.572
# 6.416
# 5.859
# 6.546
# 6.02
# 6.315
# 6.86
# 6.98
# 7.765
# 6.144
# 7.155
# 6.563
# 5.604
# 6.153
# 7.831
# 6.782
# 6.556
# 7.185
# 6.9510000000000005
# 6.739
# 7.178
# 6.8
# 6.604
# 7.875
# 7.287000000000001
# 7.107
# 7.274
# 6.975
# 7.135
# 6.162000000000001
# 7.61
# 7.853
# 8.033999999999999
# 5.891
# 6.3260000000000005
# 5.7829999999999995
# 6.064
# 5.343999999999999
# 5.96
# 5.404
# 5.807
# 6.375
# 5.412000000000001
# 6.182
# 5.888
# 6.642
# 5.9510000000000005
# 6.372999999999999
# 6.9510000000000005
# 6.164
# 6.879
# 6.617999999999999
# 8.266
# 8.725
# 8.04
# 7.162999999999999
# 7.686
# 6.5520000000000005
# 5.981
# 7.412000000000001
# 8.337
# 8.247
# 6.726
# 6.086
# 6.631
# 7.358
# 6.481
# 6.606
# 6.897
# 6.095
# 6.358
# 6.393
# 5.593
# 5.605
# 6.108
# 6.226
# 6.433
# 6.718
# 6.487
# 6.438
# 6.957000000000001
# 8.259
# 6.108
# 5.876
# 7.454
# 8.704
# 7.332999999999999
# 6.8420000000000005
# 7.202999999999999
# 7.52
# 8.398
# 7.327000000000001
# 7.206
# 5.56
# 7.013999999999999
# 8.297
# 7.47
# 5.92
# 5.856
# 6.24
# 6.537999999999999
# 7.691
# 6.757999999999999
# 6.854
# 7.267
# 6.8260000000000005
# 6.482
# 6.812
# 7.82
# 6.968
# 7.645
# 7.922999999999999
# 7.087999999999999
# 6.452999999999999
# 6.23
# 6.209
# 6.315
# 6.565
# 6.861000000000001
# 7.148
# 6.63
# 6.127000000000001
# 6.0089999999999995
# 6.678
# 6.5489999999999995
# 5.79
# 6.345
# 7.041
# 6.871
# 6.59
# 6.495
# 6.982
# 7.236000000000001
# 6.6160000000000005
# 7.42
# 6.849
# 6.635
# 5.972
# 4.973
# 6.122000000000001
# 6.023
# 6.266
# 6.567
# 5.705
# 5.914
# 5.782
# 6.382000000000001
# 6.1129999999999995
# 6.426
# 6.376
# 6.041
# 5.707999999999999
# 6.415
# 6.431
# 6.312
# 6.082999999999999
# 5.867999999999999
# 6.332999999999999
# 6.144
# 5.706
# 6.031000000000001
# 6.316
# 6.31
# 6.037000000000001
# 5.869
# 5.895
# 6.059
# 5.985
# 5.968
# 7.2410000000000005
# 6.54
# 6.696000000000001
# 6.874
# 6.013999999999999
# 5.898
# 6.516
# 6.635
# 6.939
# 6.49
# 6.579
# 5.8839999999999995
# 6.728
# 5.662999999999999
# 5.936
# 6.212000000000001
# 6.395
# 6.127000000000001
# 6.112
# 6.398
# 6.251
# 5.362
# 5.803
# 8.78
# 3.5610000000000004
# 4.963
# 3.863
# 4.97
# 6.683
# 7.016
# 6.216
# 5.875
# 4.906000000000001
# 4.138
# 7.313
# 6.649
# 6.794
# 6.38
# 6.223
# 6.968
# 6.545
# 5.5360000000000005
# 5.52
# 4.368
# 5.277
# 4.652
# 5.0
# 4.88
# 5.39
# 5.712999999999999
# 6.051
# 5.0360000000000005
# 6.193
# 5.8870000000000005
# 6.471
# 6.405
# 5.747000000000001
# 5.452999999999999
# 5.852
# 5.987
# 6.343
# 6.404
# 5.349
# 5.531000000000001
# 5.683
# 4.138
# 5.608
# 5.617000000000001
# 6.852
# 5.757000000000001
# 6.657
# 4.628
# 5.155
# 4.519
# 6.434
# 6.782
# 5.303999999999999
# 5.957000000000001
# 6.824
# 6.4110000000000005
# 6.006
# 5.648
# 6.103
# 5.565
# 5.896
# 5.837000000000001
# 6.202000000000001
# 6.193
# 6.38
# 6.348
# 6.832999999999999
# 6.425
# 6.436
# 6.207999999999999
# 6.629
# 6.461
# 6.152
# 5.935
# 5.627000000000001
# 5.818
# 6.406000000000001
# 6.218999999999999
# 6.485
# 5.854
# 6.459
# 6.341
# 6.251
# 6.185
# 6.417000000000001
# 6.749
# 6.655
# 6.297000000000001
# 7.393
# 6.728
# 6.525
# 5.976
# 5.936
# 6.301
# 6.081
# 6.7010000000000005
# 6.376
# 6.317
# 6.513
# 6.209
# 5.7589999999999995
# 5.952000000000001
# 6.002999999999999
# 5.926
# 5.712999999999999
# 6.167000000000001
# 6.229
# 6.437
# 6.98
# 5.4270000000000005
# 6.162000000000001
# 6.484
# 5.303999999999999
# 6.185
# 6.229
# 6.242000000000001
# 6.75
# 7.061
# 5.7620000000000005
# 5.871
# 6.312
# 6.114
# 5.905
# 5.454
# 5.414
# 5.093
# 5.983
# 5.983
# 5.707000000000001
# 5.926
# 5.67
# 5.39
# 5.794
# 6.019
# 5.569
# 6.027
# 6.593
# 6.12
# 6.976
# 6.794
# 6.03

# %%
for ind,row in boston.iterrows():
  print(row['CRIM'])
# Out:
# 0.00632
# 0.02731
# 0.02729
# 0.032369999999999996
# 0.06905
# 0.02985
# 0.08829
# 0.14455
# 0.21124
# 0.17004
# 0.22489
# 0.11747
# 0.09378
# 0.62976
# 0.6379600000000001
# 0.62739
# 1.05393
# 0.7842
# 0.80271
# 0.7258
# 1.25179
# 0.8520399999999999
# 1.2324700000000002
# 0.9884299999999999
# 0.75026
# 0.84054
# 0.67191
# 0.9557700000000001
# 0.77299
# 1.00245
# 1.13081
# 1.3547200000000001
# 1.38799
# 1.15172
# 1.6128200000000001
# 0.06417
# 0.09744
# 0.08014
# 0.17505
# 0.027630000000000002
# 0.033589999999999995
# 0.12744
# 0.1415
# 0.15936
# 0.12269000000000001
# 0.17142000000000002
# 0.18836
# 0.22926999999999997
# 0.25387
# 0.21977
# 0.08872999999999999
# 0.04337
# 0.0536
# nan
# 0.0136
# 0.01311
# 0.02055
# 0.01432
# 0.15445
# 0.10328
# 0.14932
# 0.17171
# 0.11027
# 0.1265
# 0.01951
# 0.03584
# 0.043789999999999996
# 0.05789
# 0.13554000000000002
# 0.12816
# 0.08826
# 0.15875999999999998
# 0.09164
# 0.19539
# 0.07896
# 0.09512000000000001
# 0.10153
# 0.08707000000000001
# 0.05646
# 0.08387
# 0.04113
# 0.04462
# 0.03659
# 0.03551
# 0.050589999999999996
# 0.05735
# 0.051879999999999996
# 0.07151
# 0.0566
# 0.053020000000000005
# 0.04684
# 0.03932
# 0.04203
# 0.02875
# 0.04294
# 0.12204000000000001
# 0.11504
# 0.12082999999999999
# 0.08187
# 0.0686
# 0.14866
# 0.11432
# 0.22876
# 0.21161
# 0.1396
# 0.13262000000000002
# 0.1712
# 0.13117
# 0.12802
# 0.26363000000000003
# 0.10793
# 0.10084
# 0.12329000000000001
# 0.22211999999999998
# 0.14231
# nan
# 0.13158
# 0.15098
# 0.13058
# 0.14476
# 0.06899
# 0.07165
# 0.09299
# 0.15037999999999999
# 0.09849
# 0.16902
# 0.38735
# 0.25915
# 0.32543
# 0.88125
# 0.34006
# 1.19294
# 0.59005
# 0.32982
# 0.9761700000000001
# 0.55778
# 0.32264
# 0.35233000000000003
# 0.2498
# 0.54452
# 0.2909
# 1.6286399999999999
# 3.32105
# 4.0974
# 2.7797400000000003
# 2.37934
# 2.15505
# 2.36862
# 2.3309900000000003
# 2.7339700000000002
# 1.6566
# 1.49632
# 1.12658
# 2.14918
# 1.41385
# 3.5350099999999998
# 2.4466799999999997
# 1.22358
# 1.34284
# 1.4250200000000002
# 1.27346
# 1.46336
# 1.8337700000000001
# 1.51902
# 2.2423599999999997
# 2.924
# 2.01019
# 1.8002799999999999
# 2.3004
# 2.4495299999999998
# 1.2074200000000002
# 2.3139
# 0.13914
# 0.09178
# 0.08447
# 0.06663999999999999
# 0.07022
# 0.05425
# 0.06642
# 0.0578
# 0.06588
# 0.06888
# 0.09103
# nan
# 0.08308
# 0.06047
# 0.05602000000000001
# 0.07875
# 0.12579
# 0.0837
# 0.09068
# nan
# nan
# 0.02187
# 0.01439
# 0.01381
# nan
# 0.04666
# 0.03768
# 0.0315
# 0.01778
# 0.03445
# 0.021769999999999998
# 0.0351
# 0.02009
# 0.13642
# 0.22969
# 0.25199
# 0.13587
# 0.43571000000000004
# 0.17446
# 0.37578
# 0.21719000000000002
# 0.14052
# 0.28955
# 0.19802
# 0.0456
# 0.07013
# 0.11069000000000001
# 0.11425
# 0.35809
# 0.40771
# 0.62356
# 0.6147
# 0.31533
# 0.52693
# 0.38214000000000004
# 0.41238
# 0.29819
# nan
# 0.537
# 0.46296000000000004
# 0.57529
# 0.33147
# 0.44791000000000003
# 0.33045
# nan
# 0.51183
# 0.08244
# 0.09252
# 0.11329000000000002
# nan
# 0.1029
# 0.12757000000000002
# 0.20608
# 0.19133
# 0.33983
# 0.19657
# 0.16439
# 0.19072999999999998
# 0.1403
# 0.21409
# 0.08221
# 0.36894
# 0.04819
# 0.035480000000000005
# 0.015380000000000001
# 0.61154
# 0.66351
# 0.65665
# 0.5401100000000001
# 0.5341199999999999
# nan
# 0.82526
# 0.55007
# 0.76162
# 0.7857
# 0.57834
# 0.5405
# 0.09065
# 0.29916
# 0.16211
# 0.1146
# 0.22188000000000002
# 0.05644
# 0.09604
# 0.10469
# 0.061270000000000005
# 0.07977999999999999
# 0.21038
# 0.03578
# 0.03705
# 0.06129
# 0.015009999999999999
# 0.009059999999999999
# 0.01096
# 0.01965
# 0.03871
# nan
# 0.04297
# 0.035019999999999996
# 0.07886
# 0.03615
# 0.08265
# 0.08199
# 0.12932000000000002
# 0.053720000000000004
# 0.14103
# 0.06466000000000001
# 0.05561
# 0.04417
# 0.03537
# nan
# 0.1
# 0.05515
# 0.05479
# 0.07503
# 0.049319999999999996
# 0.49298000000000003
# 0.3494
# 2.63548
# 0.7904100000000001
# 0.26169000000000003
# 0.26938
# 0.3692
# 0.25356
# 0.31827
# 0.24522
# 0.40202
# 0.47547
# 0.1676
# 0.18159
# 0.35114
# 0.28392
# 0.34109
# 0.19186
# 0.30346999999999996
# 0.24103000000000002
# 0.06617
# 0.06724
# 0.045439999999999994
# 0.050230000000000004
# 0.03466
# 0.05083
# 0.037380000000000004
# 0.03961
# 0.03427
# 0.030410000000000003
# 0.03306
# 0.054970000000000005
# 0.06151
# 0.013009999999999999
# 0.024980000000000002
# 0.02543
# 0.030489999999999996
# 0.03113
# 0.06162
# 0.0187
# 0.015009999999999999
# 0.02899
# 0.062110000000000005
# 0.0795
# 0.07244
# 0.01709
# 0.04301
# 0.10659
# 8.98296
# 3.8497
# 5.20177
# 4.26131
# 4.541919999999999
# 3.83684
# 3.6782199999999996
# 4.22239
# 3.4742800000000003
# 4.55587
# 3.69695
# 13.5222
# 4.898219999999999
# nan
# 6.53876
# 9.2323
# 8.26725
# 11.1081
# 18.4982
# 19.6091
# 15.288
# 9.82349
# 23.6482
# 17.8667
# 88.9762
# 15.8744
# 9.18702
# 7.9924800000000005
# 20.0849
# 16.8118
# 24.3938
# 22.5971
# 14.3337
# 8.15174
# 6.96215
# 5.29305
# 11.5779
# nan
# nan
# 8.71675
# 5.87205
# 7.67202
# 38.3518
# 9.91655
# 25.0461
# 14.2362
# 9.59571
# 24.8017
# 41.5292
# 67.9208
# 20.7162
# 11.9511
# 7.40389
# nan
# 51.1358
# 14.0507
# 18.811
# 28.6558
# 45.7461
# 18.0846
# 10.8342
# 25.9406
# 73.5341
# 11.8123
# 11.0874
# 7.022589999999999
# 12.0482
# 7.05042
# 8.792119999999999
# 15.8603
# nan
# 37.6619
# 7.36711
# 9.33889
# nan
# 10.0623
# 6.44405
# 5.5810699999999995
# 13.9134
# 11.1604
# 14.4208
# 15.1772
# 13.6781
# 9.39063
# 22.0511
# 9.72418
# 5.66637
# 9.96654
# 12.8023
# 10.6718
# 6.288069999999999
# 9.92485
# 9.329089999999999
# 7.52601
# 6.71772
# 5.44114
# 5.09017
# 8.24809
# 9.513630000000001
# 4.75237
# 4.668830000000001
# 8.20058
# 7.75223
# 6.80117
# nan
# 3.69311
# 6.65492
# 5.82115
# 7.83932
# nan
# 3.7749800000000002
# 4.422280000000001
# 15.5757
# 13.0751
# 4.34879
# 4.03841
# 3.56868
# 4.64689
# 8.05579
# 6.39312
# 4.87141
# 15.0234
# 10.232999999999999
# 14.3337
# 5.8240099999999995
# 5.7081800000000005
# 5.73116
# 2.81838
# 2.37857
# 3.6736699999999995
# 5.69175
# 4.8356699999999995
# 0.15086
# 0.18337
# 0.20745999999999998
# 0.10574000000000001
# 0.11132
# 0.17331
# 0.27957
# 0.17899
# 0.2896
# 0.26838
# 0.23911999999999997
# 0.17783
# 0.22438000000000002
# 0.06262999999999999
# 0.04527
# 0.06076
# 0.10959
# 0.04741

# %%
for ind,row in boston.iterrows():
  print(ind, row['MEDV'])
# Out:
# 0 24.0
# 1 21.6
# 2 34.7
# 3 33.4
# 4 36.2
# 5 28.7
# 6 22.9
# 7 27.1
# 8 16.5
# 9 18.9
# 10 15.0
# 11 18.9
# 12 21.7
# 13 20.4
# 14 18.2
# 15 19.9
# 16 23.1
# 17 17.5
# 18 20.2
# 19 18.2
# 20 13.6
# 21 19.6
# 22 15.2
# 23 14.5
# 24 15.6
# 25 13.9
# 26 16.6
# 27 14.8
# 28 18.4
# 29 21.0
# 30 12.7
# 31 14.5
# 32 13.2
# 33 13.1
# 34 13.5
# 35 18.9
# 36 20.0
# 37 21.0
# 38 24.7
# 39 30.8
# 40 34.9
# 41 26.6
# 42 25.3
# 43 24.7
# 44 21.2
# 45 19.3
# 46 20.0
# 47 16.6
# 48 14.4
# 49 19.4
# 50 19.7
# 51 20.5
# 52 25.0
# 53 23.4
# 54 18.9
# 55 35.4
# 56 24.7
# 57 31.6
# 58 23.3
# 59 19.6
# 60 18.7
# 61 16.0
# 62 22.2
# 63 25.0
# 64 33.0
# 65 23.5
# 66 19.4
# 67 22.0
# 68 17.4
# 69 20.9
# 70 24.2
# 71 21.7
# 72 22.8
# 73 23.4
# 74 24.1
# 75 21.4
# 76 20.0
# 77 20.8
# 78 21.2
# 79 20.3
# 80 28.0
# 81 23.9
# 82 24.8
# 83 22.9
# 84 23.9
# 85 26.6
# 86 22.5
# 87 22.2
# 88 23.6
# 89 28.7
# 90 22.6
# 91 22.0
# 92 22.9
# 93 25.0
# 94 20.6
# 95 28.4
# 96 21.4
# 97 38.7
# 98 43.8
# 99 33.2
# 100 27.5
# 101 26.5
# 102 18.6
# 103 19.3
# 104 20.1
# 105 19.5
# 106 19.5
# 107 20.4
# 108 19.8
# 109 19.4
# 110 21.7
# 111 22.8
# 112 18.8
# 113 18.7
# 114 18.5
# 115 18.3
# 116 21.2
# 117 19.2
# 118 20.4
# 119 19.3
# 120 22.0
# 121 20.3
# 122 20.5
# 123 17.3
# 124 18.8
# 125 21.4
# 126 15.7
# 127 16.2
# 128 18.0
# 129 14.3
# 130 19.2
# 131 19.6
# 132 23.0
# 133 18.4
# 134 15.6
# 135 18.1
# 136 17.4
# 137 17.1
# 138 13.3
# 139 17.8
# 140 14.0
# 141 14.4
# 142 13.4
# 143 15.6
# 144 11.8
# 145 13.8
# 146 15.6
# 147 14.6
# 148 17.8
# 149 15.4
# 150 21.5
# 151 19.6
# 152 15.3
# 153 19.4
# 154 17.0
# 155 15.6
# 156 13.1
# 157 41.3
# 158 24.3
# 159 23.3
# 160 27.0
# 161 50.0
# 162 50.0
# 163 50.0
# 164 22.7
# 165 25.0
# 166 50.0
# 167 23.8
# 168 23.8
# 169 22.3
# 170 17.4
# 171 19.1
# 172 23.1
# 173 23.6
# 174 22.6
# 175 29.4
# 176 23.2
# 177 24.6
# 178 29.9
# 179 37.2
# 180 39.8
# 181 36.2
# 182 37.9
# 183 32.5
# 184 26.4
# 185 29.6
# 186 50.0
# 187 32.0
# 188 29.8
# 189 34.9
# 190 37.0
# 191 30.5
# 192 36.4
# 193 31.1
# 194 29.1
# 195 50.0
# 196 33.3
# 197 30.3
# 198 34.6
# 199 34.9
# 200 32.9
# 201 24.1
# 202 42.3
# 203 48.5
# 204 50.0
# 205 22.6
# 206 24.4
# 207 22.5
# 208 24.4
# 209 20.0
# 210 21.7
# 211 19.3
# 212 22.4
# 213 28.1
# 214 23.7
# 215 25.0
# 216 23.3
# 217 28.7
# 218 21.5
# 219 23.0
# 220 26.7
# 221 21.7
# 222 27.5
# 223 30.1
# 224 44.8
# 225 50.0
# 226 37.6
# 227 31.6
# 228 46.7
# 229 31.5
# 230 24.3
# 231 31.7
# 232 41.7
# 233 48.3
# 234 29.0
# 235 24.0
# 236 25.1
# 237 31.5
# 238 23.7
# 239 23.3
# 240 22.0
# 241 20.1
# 242 22.2
# 243 23.7
# 244 17.6
# 245 18.5
# 246 24.3
# 247 20.5
# 248 24.5
# 249 26.2
# 250 24.4
# 251 24.8
# 252 29.6
# 253 42.8
# 254 21.9
# 255 20.9
# 256 44.0
# 257 50.0
# 258 36.0
# 259 30.1
# 260 33.8
# 261 43.1
# 262 48.8
# 263 31.0
# 264 36.5
# 265 22.8
# 266 30.7
# 267 50.0
# 268 43.5
# 269 20.7
# 270 21.1
# 271 25.2
# 272 24.4
# 273 35.2
# 274 32.4
# 275 32.0
# 276 33.2
# 277 33.1
# 278 29.1
# 279 35.1
# 280 45.4
# 281 35.4
# 282 46.0
# 283 50.0
# 284 32.2
# 285 22.0
# 286 20.1
# 287 23.2
# 288 22.3
# 289 24.8
# 290 28.5
# 291 37.3
# 292 27.9
# 293 23.9
# 294 21.7
# 295 28.6
# 296 27.1
# 297 20.3
# 298 22.5
# 299 29.0
# 300 24.8
# 301 22.0
# 302 26.4
# 303 33.1
# 304 36.1
# 305 28.4
# 306 33.4
# 307 28.2
# 308 22.8
# 309 20.3
# 310 16.1
# 311 22.1
# 312 19.4
# 313 21.6
# 314 23.8
# 315 16.2
# 316 17.8
# 317 19.8
# 318 23.1
# 319 21.0
# 320 23.8
# 321 23.1
# 322 20.4
# 323 18.5
# 324 25.0
# 325 24.6
# 326 23.0
# 327 22.2
# 328 19.3
# 329 22.6
# 330 19.8
# 331 17.1
# 332 19.4
# 333 22.2
# 334 20.7
# 335 21.1
# 336 19.5
# 337 18.5
# 338 20.6
# 339 19.0
# 340 18.7
# 341 32.7
# 342 16.5
# 343 23.9
# 344 31.2
# 345 17.5
# 346 17.2
# 347 23.1
# 348 24.5
# 349 26.6
# 350 22.9
# 351 24.1
# 352 18.6
# 353 30.1
# 354 18.2
# 355 20.6
# 356 17.8
# 357 21.7
# 358 22.7
# 359 22.6
# 360 25.0
# 361 19.9
# 362 20.8
# 363 16.8
# 364 21.9
# 365 27.5
# 366 21.9
# 367 23.1
# 368 50.0
# 369 50.0
# 370 50.0
# 371 50.0
# 372 50.0
# 373 13.8
# 374 13.8
# 375 15.0
# 376 13.9
# 377 13.3
# 378 13.1
# 379 10.2
# 380 10.4
# 381 10.9
# 382 11.3
# 383 12.3
# 384 8.8
# 385 7.2
# 386 10.5
# 387 7.4
# 388 10.2
# 389 11.5
# 390 15.1
# 391 23.2
# 392 9.7
# 393 13.8
# 394 12.7
# 395 13.1
# 396 12.5
# 397 8.5
# 398 5.0
# 399 6.3
# 400 5.6
# 401 7.2
# 402 12.1
# 403 8.3
# 404 8.5
# 405 5.0
# 406 11.9
# 407 27.9
# 408 17.2
# 409 27.5
# 410 15.0
# 411 17.2
# 412 17.9
# 413 16.3
# 414 7.0
# 415 7.2
# 416 7.5
# 417 10.4
# 418 8.8
# 419 8.4
# 420 16.7
# 421 14.2
# 422 20.8
# 423 13.4
# 424 11.7
# 425 8.3
# 426 10.2
# 427 10.9
# 428 11.0
# 429 9.5
# 430 14.5
# 431 14.1
# 432 16.1
# 433 14.3
# 434 11.7
# 435 13.4
# 436 9.6
# 437 8.7
# 438 8.4
# 439 12.8
# 440 10.5
# 441 17.1
# 442 18.4
# 443 15.4
# 444 10.8
# 445 11.8
# 446 14.9
# 447 12.6
# 448 14.1
# 449 13.0
# 450 13.4
# 451 15.2
# 452 16.1
# 453 17.8
# 454 14.9
# 455 14.1
# 456 12.7
# 457 13.5
# 458 14.9
# 459 20.0
# 460 16.4
# 461 17.7
# 462 19.5
# 463 20.2
# 464 21.4
# 465 19.9
# 466 19.0
# 467 19.1
# 468 19.1
# 469 20.1
# 470 19.9
# 471 19.6
# 472 23.2
# 473 29.8
# 474 13.8
# 475 13.3
# 476 16.7
# 477 12.0
# 478 14.6
# 479 21.4
# 480 23.0
# 481 23.7
# 482 25.0
# 483 21.8
# 484 20.6
# 485 21.2
# 486 19.1
# 487 20.6
# 488 15.2
# 489 7.0
# 490 8.1
# 491 13.6
# 492 20.1
# 493 21.8
# 494 24.5
# 495 23.1
# 496 19.7
# 497 18.3
# 498 21.2
# 499 17.5
# 500 16.8
# 501 22.4
# 502 20.6
# 503 23.9
# 504 22.0
# 505 11.9
