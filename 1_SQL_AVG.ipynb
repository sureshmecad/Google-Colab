# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Google-Colab/blob/master/1_SQL_AVG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - The **AVG()** function returns the **average value** of a **numeric column.**

# %% [markdown]
# ### **AVG() Syntax**

# %% [markdown]
#       SELECT AVG(column_name)
#
#       FROM table_name
#
#       WHERE condition;

# %% [markdown]
# - **Note:** NULL values are ignored.

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)
