# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Google-Colab/blob/master/1_for_enumerate_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - https://www.youtube.com/watch?v=iDgkSu5OorU ---> Amulya
#
# - https://www.youtube.com/watch?v=uPT-LkYSP_o ---> How to Use enumerate() in Python
#
# - https://www.youtube.com/watch?v=3oeVZR2CWd8 --->
#
# - https://www.youtube.com/watch?v=BEDRP7DezQk

# %% [markdown]
# -----------------

# %% [markdown]
# # **Syntax**

# %% [markdown]
# #### **enumerate(iterable)**
#
# where,
#
# #### **iterable** ---> **List, tuple, set, dictionary, string**

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![4.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ----------------------

# %% [markdown]
# #### **Without Enumerate function**

# %%
for i in range(len(color)):
  print(i, color[i])
# Out:
# 0 red
# 1 blue
# 2 yellow

# %% [markdown]
# #### **with Enumerate function**

# %%
for index,value in enumerate(color):
  print(index, value)
# Out:
# 0 red
# 1 blue
# 2 yellow

# %% [markdown]
# --------------------
