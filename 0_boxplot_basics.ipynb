# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Google-Colab/blob/master/0_boxplot_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * [1) What is Boxplot?](#1)
#
# * [2) Boxplot on a Normal Distribution](#2)
#
# * [3) Why are box plots useful?](#3)
#
#   * [a) Box plots are useful as they show the average score of a dataset](#a)
#
#   * [b) Box plots are useful as they show the skewness of a data set](#b)
#
#   * [c) Box plots are useful as they show the dispersion of a data set](#c)
#
#   * [d) Box plots are useful as they show outliers within a data set](#d)

# %% [markdown]
# ### **1) What is Boxplot?**

# %% [markdown]
# - Tell you the values of your **outliers**
#
# - Identify if data is **symmetrical**
#
# - Determine how tightly data is grouped
#
# - See if your data is **skewed**

# %% [markdown]
# - In **descriptive statistics**, a **boxplot** (also known as **box and whisker plot**) is a type of chart often used in **EDA**.
#
# - **Box plots** visually show the **distribution of numerical data and skewness** through displaying the data quartiles (or percentiles) and averages.

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# - **median (Q2/50th Percentile):**
#
#  - The middle value of the dataset.
#
#  - The **median** marks the **mid-point of the data** and is shown by the line that divides the box into two parts (sometimes known as the **second quartile**). Half the scores are greater than or equal to this value and half are less.

# %% [markdown]
# - **Lower Quartile (or) first quartile (Q1/25th Percentile):**
#
#  - The **middle number** between the **smallest** number (not the “minimum”) and the **median** of the dataset.
#
#  - **25%** of scores fall below the lower quartile value

# %% [markdown]
# - **Upper Quartile (or) third quartile (Q3/75th Percentile):**
#
#  - The **middle** value between the **median** and the **highest value** (not the “maximum”) of the dataset.
#
#  - **75%** of the scores fall below the upper quartile value (also known as the third quartile). Thus, 25% of data are above this value.

# %% [markdown]
# - **interquartile range (IQR):**
#
#  - **25th to the 75th percentile**. The Interquartile range (IQR) is the **spread of the middle 50% of the data values.**
#
#  - This is the box plot showing the middle 50% of scores (i.e., the range between the 25th and 75th percentile)
#
#  - **IQR = Q3 – Q1**

# %% [markdown]
# - **whiskers (shown in blue)**
#
#  - The upper and lower whiskers represent scores outside the middle 50% (i.e. the lower 25% of scores and the upper 25% of scores)

# %% [markdown]
# - **outliers (shown as green circles)**

# %% [markdown]
# - **“maximum”:**
#
#  - The highest score, excluding **outliers** (shown at the end of the right whisker)
#
#  - **Q3 + 1.5*IQR**

# %% [markdown]
# - **“minimum”:**
#
#  - The lowest score, excluding **outliers** (shown at the end of the left whisker)
#
#  - **Q1 -1.5*IQR**

# %% [markdown]
# ------------------------

# %% [markdown]
# ### **2) Boxplot on a Normal Distribution**

# %% [markdown]
# - How **outliers** are (for a normal distribution) **7%** of the data.

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ---------------------------

# %% [markdown]
# ### **3) Why are box plots useful?**

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# - Box plots divide the data into **sections** that each contain approximately **25%** of the data in that set.

# %% [markdown]
# - Box plots are useful as they provide a visual summary of the data enabling researchers to quickly identify **mean values, the dispersion of the dataset, and signs of skewness.**

# %% [markdown]
# - Note the image above represents data which is a **perfect normal distribution** and most box plots will not conform to this symmetry (where **each quartile is the same length**).

# %% [markdown]
# #### **a) Box plots are useful as they show the average score of a dataset**

# %% [markdown]
# - The median is the average value from a set of data and is shown by the line that devides the box into two parts. Half the scores are greater than or equal to this value and half are less.

# %% [markdown]
# #### **b) Box plots are useful as they show the skewness of a data set**

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# - The **box plot shape** will show if a statistical data set is **normally distributed or skewed.**

# %% [markdown]
# - When the **median is in the middle of the box**, and the **whiskers** are about the **same on both sides of the box**, then the distribution is **symmetric**.

# %% [markdown]
# - When the **median** is closer to the **bottom** of the box, and if the **whisker** is **shorter on the lower** end of the box, then the distribution is positively skewed (**skewed right**).

# %% [markdown]
# - When the **median** is closer to the **top** of the box, and if the **whisker** is **shorter on the upper** end of the box, then the distribution is negatively skewed (**skewed left**).

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# #### **c) Box plots are useful as they show the dispersion of a data set**

# %% [markdown]
# - In statistics, **dispersion(also called variability, scatter or spread)** is the extent to which a distribution is **stretched or squeezed**.
#
# - The smallest value and largest value are found at the end of the 'whiskers' and are useful for providing a visual indicator regarding the spread of scores (e.g. the range)

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# - The interquartile range (IQR) is the box plot showing the middle 50% of scores and can be calculated by subtracting the lower quartile from the upper quartile (e.g. Q3−Q1).

# %% [markdown]
# #### **d) Box plots are useful as they show outliers within a data set**

# %% [markdown]
# - An outlier is an observation that is numerically distant from the rest of the data.
#
# - When reviewing a box plot, an outlier is defined as a data point that is located outside the whiskers of the box plot.

# %% [markdown]
# ![3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# - For example, outside 1.5 times the interquartile range above the upper quartile and below the lower quartile (Q1 - 1.5 * IQR or Q3 + 1.5 * IQR).

# %% [markdown]
# -------------------

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# -------------------------

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# #### **Reference**

# %% [markdown]
# - https://www.youtube.com/watch?v=vQ0L-gSUyvc
#
# - https://www.simplypsychology.org/boxplots.html
