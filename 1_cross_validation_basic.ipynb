# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Google-Colab/blob/master/1_cross_validation_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - https://www.youtube.com/watch?v=rPlBijVFw7k ---> Unfold Datascience
#
# - https://www.youtube.com/watch?v=yxqcHWQKkdA ---> Leave One Out Cross Validation in Machine Learning | LOOCV

# %% [markdown]
# ----------------------

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ----------------------

# %% [markdown]
# ![3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# #### **Types of Cross Validation**

# %% [markdown]
# ##### **LOOCV : Leave One Out Cross Validation**
# - model trains from 99% of data and predicts on 1% data
#
# - **Disadvantage:** Since **one** record taking out for test so there is high possibility of **high variance**.

# %% [markdown]
# #### **KFold**
# - **Adv:** Model is using all the data for training
# - **Low variance** (in LOOCV, test size 1; in KFold, test size 10)

# %% [markdown]
# #### **Stratified Cross Validation**
