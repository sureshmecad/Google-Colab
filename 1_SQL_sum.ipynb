# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Google-Colab/blob/master/1_SQL_sum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - The **SUM()** function returns the **total sum** of a **numeric column.**

# %% [markdown]
# ### **SUM() Syntax**

# %% [markdown]
#      SELECT SUM(column_name)
#
#      FROM table_name
#
#      WHERE condition;

# %% [markdown]
# ![3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# - The following SQL statement finds the **sum** of the **"Quantity"** fields in the **"OrderDetails"** table:

# %% [markdown]
# ![4.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# - **Note:** NULL values are ignored.
