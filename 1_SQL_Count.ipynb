# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Google-Colab/blob/master/1_SQL_Count.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### **COUNT() Syntax**

# %% [markdown]
# - The **COUNT()** function returns the **number of rows** that matches a specified criterion.

# %% [markdown]
#      SELECT COUNT(column_name)
#
#      FROM table_name
#
#      WHERE condition;

# %% [markdown]
# --------------

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %%
SELECT COUNT(ProductID)
FROM Products;

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)
