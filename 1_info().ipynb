# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Google-Colab/blob/master/1_info().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### **Syntax**
# DataFrame.info(verbose=None, buf=None, max_cols=None, memory_usage=None, null_counts=None)

# %% [markdown]
# ### **Parameters :**
#
# - **verbose :** Whether to print the full summary. None follows the display.max_info_columns setting. True or False overrides the display.max_info_columns setting.
#
# - **buf :** writable buffer, defaults to sys.stdout
#
# - **max_cols :** Determines whether full summary or short summary is printed. None follows the display.max_info_columns setting.
#
# - **memory_usage :** Specifies whether total memory usage of the DataFrame elements (including index) should be displayed. None follows the display.memory_usage setting. True or False overrides the display.memory_usage setting. A value of ‘deep’ is equivalent of True, with deep introspection. Memory usage is shown in human-readable units (base-2 representation).
#
# - **null_counts :** Whether to show the non-null counts. If None, then only show if the frame is smaller than max_info_rows and max_info_columns. If True, always show counts. If False, never show counts.

# %% [markdown]
# ------------------

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
nba = pd.read_csv("/content/drive/MyDrive/TMLC/Android.zip")
nba.head(3)
# Out:
#                        App  ... Class
# 0  Canada Post Corporation  ...     0
# 1                Word Farm  ...     0
# 2     Fortunes of War FREE  ...     0
#
# [3 rows x 184 columns]

# %% [markdown]
# #### **1) print the full summary of the dataframe**

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Columns: 184 entries, App to Class
# dtypes: float64(3), int64(176), object(5)
# memory usage: 42.1+ MB

# %% [markdown]
# - As we can see in the output, the summary includes list of all **columns with their data types and the number of non-null values in each column.** we also have the value of rangeindex provided for the index axis.

# %% [markdown]
# #### **2) In order to print the short summary, we can use the verbose parameter and set it to False.**

# %%
# Prints a summary of columns count and its dtypes but not per column information
nba.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Columns: 184 entries, App to Class
# dtypes: float64(3), int64(176), object(5)
# memory usage: 42.1+ MB

# %% [markdown]
# #### **3) To print a full summary of the dataframe and exclude the null-counts**
#
# - In order to print the **full summary**, with **null-counts excluded**, we can use null-counts parameter and set it to be false.

# %% [markdown]
#       nba.info(verbose = True, null_counts = False)
#                        (or)
#       nba.info(verbose=True)

# %%
# Print the full summary of the dataframe with null count excluded
nba.info(verbose = True, null_counts = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 184 columns):
#  #   Column                                                                                  Dtype
# ---  ------                                                                                  -----
#  0   App                                                                                     object
#  1   Package                                                                                 object
#  2   Category                                                                                object
#  3   Description                                                                             object
#  4   Rating                                                                                  float64
#  5   Number of ratings                                                                       int64
# ...

# %% [markdown]
# #### **4) To print a full summary of the dataframe and include the null-counts**

# %%
# Print the full summary of the dataframe with null count excluded
nba.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 184 columns):
#  #   Column                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                  --------------  -----
#  0   App                                                                                     29998 non-null  object
#  1   Package                                                                                 29999 non-null  object
#  2   Category                                                                                29999 non-null  object
#  3   Description                                                                             29996 non-null  object
#  4   Rating                                                                                  29999 non-null  float64
# ...
