# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Google-Colab/blob/master/0_VIF_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - https://www.youtube.com/watch?v=qk7M749HKBs ---> Multicollinearity & VIF (Variance Inflation Factor)
#
# - https://www.youtube.com/watch?v=6JpmgzCAusI ---> Variance Inflation Factor In Python
#
# ### **Pending**
#
#  - Need to update this notebook with code from videos

# %% [markdown]
# ----------------------

# %% [markdown]
# --------------

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ----------------------

# %% [markdown]
# ![3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# -------------------------

# %% [markdown]
# ![4.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# -------------------------

# %% [markdown]
# ![5.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ---------------------

# %% [markdown]
# ![6.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# -----------------------------

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ----------------------

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# --------------------

# %% [markdown]
# ![3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ------------------------

# %% [markdown]
# ![4.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ------------------
