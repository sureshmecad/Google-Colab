# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Google-Colab/blob/master/2_violinplot_tips.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - https://seaborn.pydata.org/generated/seaborn.violinplot.html --> refer for more graphs
#
# - https://www.geeksforgeeks.org/violinplot-using-seaborn-in-python/

# %% [markdown]
# ----------------------

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
tips = sns.load_dataset("tips")

# %%
plt.figure(figsize=(9,8))
ax = sns.violinplot(x=tips["total_bill"])

# %%
plt.figure(figsize=(9,8))
ax = sns.violinplot(x="day", y="total_bill", data=tips)

# %%
plt.figure(figsize=(11,9))
ax = sns.violinplot(x="day", y="total_bill", hue="smoker",
                    data=tips, palette="muted")

# %%
plt.figure(figsize=(12,10))
ax = sns.violinplot(x="day", y="total_bill", hue="smoker",
                    data=tips, palette="muted", split=True)
