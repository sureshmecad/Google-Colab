# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Google-Colab/blob/master/1_zip_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - https://www.youtube.com/watch?v=qj-V2Ep4coY ---> Zip Function in Python
#
# - https://www.youtube.com/watch?v=Kn6GRtiY4eM ---> zip() Function for Parallel Iteration

# %% [markdown]
# -----------------

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ---------------------

# %% [markdown]
# #### **List**

# %%
names = ("Navin", "Kiran", "Harish")

comps = ("Dell", "Apple", "MS")

# %%
zip_list = list(zip(names, comps))
print(zip_list)
# Out:
# [('Navin', 'Dell'), ('Kiran', 'Apple'), ('Harish', 'MS')]

# %% [markdown]
# #### **Set**

# %%
zip_set = set(zip(names, comps))
print(zip_set)
# Out:
# {('Navin', 'Dell'), ('Harish', 'MS'), ('Kiran', 'Apple')}

# %% [markdown]
# #### **Dictionary**

# %%
zip_dict = dict(zip(names, comps))
print(zip_dict)
# Out:
# {'Navin': 'Dell', 'Kiran': 'Apple', 'Harish': 'MS'}

# %% [markdown]
# #### **For Loop**

# %%
for (a,b) in zip_list:
  print(a,b)
# Out:
# Navin Dell
# Kiran Apple
# Harish MS

# %% [markdown]
# ------------------------------

# %% [markdown]
# - https://www.youtube.com/watch?v=kG6nhCinNus ---> DataDaft

# %%
# Use zip() to combine iterables like lists into tuples (elementwise)
# Useful for making separate lists into tuples

latitude = [4,5,6,4,6,2,4,5,6]
longitude = [6,3,6,3,4,5,6,8,5]

[*zip(latitude, longitude)]
# Out:
# [(4, 6), (5, 3), (6, 6), (4, 3), (6, 4), (2, 5), (4, 6), (5, 8), (6, 5)]

# %%
# Can operate on more than 2 inputs
altitude = [12,41,15,16,15,23,14,51,61]

[*zip(latitude, longitude, altitude)]
# Out:
# [(4, 6, 12),
#  (5, 3, 41),
#  (6, 6, 15),
#  (4, 3, 16),
#  (6, 4, 15),
#  (2, 5, 23),
#  (4, 6, 14),
#  (5, 8, 51),
#  (6, 5, 61)]

# %% [markdown]
# #### **Zip will only continue up to the length of the shortest input**

# %%
# Zip will only continue up to the length of the shortest input

short = [1,2,3,4]
long = [1,2,3,4,5,6,7,8]

[*zip(short, long)]
# Out:
# [(1, 1), (2, 2), (3, 3), (4, 4)]

# %% [markdown]
# #### **itertools.zip_longest**

# %%
# If you want to keep all items, use itertools.zip_longest
from itertools import zip_longest

short = [1,2,3,4]
long = [1,2,3,4,5,6,7,8]

[*zip_longest(short, long, fillvalue=None)]
# Out:
# [(1, 1), (2, 2), (3, 3), (4, 4), (None, 5), (None, 6), (None, 7), (None, 8)]
