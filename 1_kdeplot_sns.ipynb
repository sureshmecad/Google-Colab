# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Google-Colab/blob/master/1_kdeplot_sns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - https://seaborn.pydata.org/generated/seaborn.kdeplot.html

# %%
sns.kdeplot(data['hp'], shade = True , color = "Green") 

sns.kdeplot(data['hp'], shade = True , color =' blue') 

sns.kdeplot(data['hp'], shade = True , color='orange')

sns.kdeplot(data['hp'], shade=True, color="r")

sns.kdeplot(data['hp'], data['cyl'], shade=True, cmap="Purples_r", cbar=True)

sns.kdeplot(data['hp'], data['cyl'], shade=True, cmap="Blues")

# %%
# Plotting the KDE Plot 
sns.kdeplot(data['hp'], color='green', shade=True, Label='Iris_Virginica') 
  
# Setting the X and Y Label 
plt.xlabel('Sepal Length') 
plt.ylabel('Probability Density')

# %% [markdown]
# #### **cbar=True**
#
# - A **colorbar** maps the pictorial representation of values **against the original data values** and helps visualize the data in a better manner.

# %%
sn.set(style='dark',)

# %% [markdown]
# -------------

# %%
# Plotting the KDE Plot 
sns.kdeplot(iris_df.loc[(iris_df['Target']=='Iris_Virginica'), 
            'Sepal_Width'], color='green', shade=True, Label='Iris_Virginica')

sns.kdeplot(iris_df.loc[(iris_df['Target']=='Iris_Setosa'), 
            'Sepal_Width'], color='blue', shade=True, Label='Iris_Setosa')

sns.kdeplot(iris_df.loc[(iris_df['Target']=='Iris_Vercicolor'), 
            'Sepal_Width'], color='red', shade=True, Label='Iris_Vercicolor')
  
# Setting the X and Y Label 
plt.xlabel('Sepal Length') 
plt.ylabel('Probability Density')

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ----------------

# %%
# Plotting the KDE Plot 
sns.kdeplot(iris_virginica['Sepal_Length'],  
            iris_virginica['Sepal_Width'], 
            color='b', shade=True, Label=’Iris_Virginica’, 
            cmap="Blues", shade_lowest=False)

# %% [markdown]
# #### **Bivariate kdeplot for multiple sample:**

# %%
# Plotting the KDE Plot 
sns.kdeplot(iris_virginica['Sepal_Length'],  
            iris_virginica['Sepal_Width'], 
            color='b', shade=True, Label='Iris_Virginica', 
            cmap="Blues", shade_lowest=False)

sns.kdeplot(iris_vercicolor['Sepal_Length'], 
            iris_vercicolor['Sepal_Width'], 
            color='r', shade=True, Label='Iris_Vercicolor', 
            cmap="Reds", shade_lowest=False)

# %% [markdown]
# --------------

# %%
sns.kdeplot( data=geyser, x="waiting", y="duration",
    fill=True, thresh=0, levels=100, cmap="mako",)

# %%
sns.kdeplot(data=tips, x="total_bill", hue="time", multiple="stack")

# %%
sns.kdeplot( data=tips, x="total_bill", hue="size",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,)
