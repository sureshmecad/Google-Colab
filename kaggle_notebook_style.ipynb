# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Google-Colab/blob/master/kaggle_notebook_style.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <li style="font-family:'Goudy Old Style';font-weight: bold;font-size:40px;color: #c1531f  ">Loading the data</li>

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# --------------------

# %% [markdown]
# <h1 style="background-color:LimeGreen; font-family:newtimeroman; font-size:200%; text-align:center; border-radius: 15px 50px;"> 1) Load Required Libraries </h1>

# %% [markdown]
# ![3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# --------------------

# %% [markdown]
# ><div class="alert alert-info" role="alert">
# ><ul style="font-family:cursive;font-size:20px;color:  #2025bd">
# ><li > The dataset is used for this competition is synthetic, but based on a real dataset and generated using a CTGAN. The original dataset deals with predicting whether a claim will be made on an insurance policy. Although the features are anonymized, they have properties relating to real-world features.</li>
# > <li> For ideas on how to improve your score, check out the <a style="color:  black" href="https://www.kaggle.com/learn/intro-to-machine-learning" target="_blank"> <u>Intro to Machine Learning</u></a> and <a style="color:  black" href="https://www.kaggle.com/learn/intermediate-machine-learning" target="_blank">   <u>Intermediate Machine Learning</u></a> courses on Kaggle Learn.</li>
# ></ul>
# ></div>

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ------------------

# %% [markdown]
# * [1) Load Required Libraries](#1)
#
# * [2) Read Data](#2)
#
# * [3) EDA (Exploratory Data Analysis)](#3)
#
#   * [3.1) DataPrep (AutoEDA)](#3.1)
#
#     * [3.1.1) Analyze distributions with plot()](#3.1.1)
#
#     * [3.1.2) Analyze correlations with plot_correlation()](#3.1.2)
#
#     * [3.1.3) Analyze missing values with plot_missing()](#3.1.3)
#
#     * [3.1.4) Create a profile report with create_report()](#3.1.4)
#
#   * [3.2) Missing Values](#3.2)
#
#   * [3.3) Outliers](#3.3)
#
#   * [3.4) Relation between Features](#3.4)
#
# * [4) Data Preprocessing](#4)
#
# * [5) Model Building and Evaluation](#5)
#
#   * [5.1) XGBoost Classifier](#5.1)
#
#   * [5.2) LGBM Classifier](#5.2)
#
#   * [5.3) Random Forest Classifier](#5.3)
#
# * [6) LightAutoML](#6)

# %% [markdown]
# ------------------
