# %% [markdown]
# <a href="https://colab.research.google.com/github/sureshmecad/Google-Colab/blob/master/1_value_counts_All_Options.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - https://re-thought.com/pandas-value_counts/
#
# - https://kanoki.org/2020/03/09/how-to-use-pandas-count-and-value_counts/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
Android = pd.read_csv("/content/drive/MyDrive/TMLC/Android.zip")
Android.head()
# Out:
#                               App  ... Class
# 0         Canada Post Corporation  ...     0
# 1                       Word Farm  ...     0
# 2            Fortunes of War FREE  ...     0
# 3  Better Keyboard: Avatar Purple  ...     0
# 4                      Boxing Day  ...     1
#
# [5 rows x 184 columns]

# %%
Android['Price'].value_counts()
# Out:
# 0.00     24322
# 0.99      1690
# 1.99       609
# 2.99       414
# 4.99       215
#          ...
# 49.95        1
# 4.32         1
# 51.00        1
# 2.42         1
# 3.96         1
# Name: Price, Length: 425, dtype: int64

# %% [markdown]
# #### **5) value_counts() persentage counts or relative frequencies of the unique values**
#
# - Sometimes, getting a percentage count is better than the normal count. By setting **normalize=True**, the object returned will contain the relative frequencies of the unique values. The normalize parameter is set to **False** by **default.**

# %%
Android['Price'].value_counts(normalize=True)
# Out:
# 0.00     0.810760
# 0.99     0.056335
# 1.99     0.020301
# 2.99     0.013800
# 4.99     0.007167
#            ...
# 49.95    0.000033
# 4.32     0.000033
# 51.00    0.000033
# 2.42     0.000033
# 3.96     0.000033
# Name: Price, Length: 425, dtype: float64

# %% [markdown]
# - value_counts as **percentages**

# %% [markdown]
# #### **6) All columns**

# %%
for col in list(Android):
      print(col)
      print(Android[col].nunique())
# Out:
# App
# 22823
# Package
# 23485
# Category
# 30
# Description
# 23552
# Rating
# 42
# Number of ratings
# 5312
# Price
# 425
# Related apps
# 23868
# Dangerous permissions count
# 28
# Safe permissions count
# 16
# Default : Access DRM content. (S)
# 2
# Default : Access Email provider data (S)
# 2
# Default : Access all system downloads (S)
# 1
# Default : Access download manager. (S)
# 2
# Default : Advanced download manager functions. (S)
# 2
# Default : Audio File Access (S)
# 2
# Default : Install DRM content. (S)
# 2
# Default : Modify Google service configuration (S)
# 1
# Default : Modify Google settings (S)
# 2
# Default : Move application resources (S)
# 2
# Default : Read Google settings (S)
# 2
# Default : Send download notifications. (S)
# 2
# Default : Voice Search Shortcuts (S)
# 2
# Default : access SurfaceFlinger (S)
# 2
# Default : access checkin properties (S)
# 2
# Default : access the cache filesystem (S)
# 2
# Default : access to passwords for Google accounts (S)
# ...

# %%
for col in list(Android):
      print(col)
      print(Android[col].value_counts())
# Out:
# App
# Tic Tac Toe                    47
# ????????????                   25
# Slot Machine                   16
# ??????????????????             15
# Solitaire                      14
#                                ..
# Sesli SÃ¶zlÃ¼k                  1
# Golden Screen Cinemas           1
# Spelling Bee                    1
# Tic Tac Toe Neural Networks     1
# HikariTV Guide                  1
# Name: App, Length: 22823, dtype: int64
# Package
# com.shazam.android                 10
# it.medieval.blueftp                 9
# com.apostek.SlotMachine             9
# com.poynt.android                   9
# com.yellowbook.android2             8
#                                    ..
# com.m85.chumdroid                   1
# com.victoriassecret.pinknation      1
# jp.fuumin.moomin.AyaComicViewer     1
# mobi.mommadeuce.richgirl            1
# com.snapmail                        1
# Name: Package, Length: 23485, dtype: int64
# Category
# Entertainment        2827
# ...

# %%
pd.options.display.max_rows = 4000
Android['Price'].value_counts()
# Out:
# 0.00      24322
# 0.99       1690
# 1.99        609
# 2.99        414
# 4.99        215
# 1.00        202
# 9.99        167
# 3.99        149
# 1.95         92
# 1.29         92
# 1.49         86
# 1.37         72
# 5.99         59
# 1.96         57
# 1.36         47
# 1.50         46
# 6.99         46
# 2.00         43
# 7.99         43
# 2.49         41
# 1.09         34
# 3.00         32
# 1.40         31
# 1.39         31
# 1.92         30
# 8.99         30
# 1.59         29
# 1.94         24
# 4.95         22
# 1.15         21
# 2.02         19
# 1.60         18
# 1.45         17
# 1.30         16
# 1.55         16
# 1.25         16
# 1.20         16
# 2.95         15
# 5.00         14
# 1.43         14
# 14.99        14
# 1.42         14
# 1.12         14
# 4.80         14
# 19.99        14
# 1.28         12
# 1.41         12
# 1.69         11
# 2.30         11
# 2.03         10
# 9.95         10
# 1.10         10
# 1.01          9
# 2.50          9
# 1.98          9
# ...
